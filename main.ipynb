# %% [markdown]
# ### Imports

# %%
import spacy
import random
import copy
from spacy.gold import GoldParse, offsets_from_biluo_tags, biluo_tags_from_offsets
from spacy.tokens import Doc
from spacy.pipeline import EntityRecognizer
from spacy.util import minibatch, compounding
import pandas as pd
from collections import defaultdict

# %% [markdown]
# ### Training

# %%
nlp = spacy.blank('en')
print('Loaded model')
new_infixes = nlp.Defaults.infixes + (r'''[-\/\,]''',)
compiled_infixes = spacy.util.compile_infix_regex(new_infixes)
nlp.tokenizer.infix_finditer = compiled_infixes.finditer
if "ner" not in nlp.pipe_names:
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
else:
    ner = nlp.get_pipe("ner")
print('Added delims')
for x in ['StreetAddDefaulter', 'CityDefaulter', 'StateDefaulter', 'PinCodeDefaulter', 'NameDefaulter', 'AmountDefaulter', 'EvictionDateDefaulter', 'ThreatDefaulter', 'DocDateDefaulter']:
    ner.add_label(x)
print('Added labels')

# %%
dat = pd.io.excel.read_excel('/home/hackathon/data/hackathon_train_set_tabular_2.xlsx')
sentences = defaultdict(list)
nerv = defaultdict(list)
newdat = zip([dat['doc_num'][x] for x in range(20244)], [dat['sentence_num'][x] for x in range(20244)], [dat['unique_tok_id'][x] for x in range(20244)], [dat['word'][x] for x in range(20244)], [dat['ner'][x] for x in range(20244)])

for x, y, z, v, w in newdat:
    sentences[y].append(v)
    nerv[y].append(w)
    
#print(len(sentences), len(nerv))
train_data = []
for x in range(1, len(nerv)+1):
    try:
        doc = Doc(nlp.vocab, sentences[x])
        offsets = offsets_from_biluo_tags(doc, nerv[x])
        train_data.append((doc, {'entities': offsets}))
    except:
        pass

test_data = train_data[:300]
train_data = train_data[300:]

(len(test_data), len(train_data))

# %%
nlp = spacy.load('./nlpv5')
#other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
#nlp.disable_pipes(*other_pipes)
#nlp.begin_training()
for itn in range(50):
    random.shuffle(train_data)
    losses = {}
    batches = minibatch(train_data, size=compounding(256.0, 1700.0, 1.002))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
            texts,
            annotations,
            drop=0.05,
            losses=losses,
        )
    print(itn, "Losses", losses)

nlp.to_disk('./nlpv6')

# %% [markdown]
# ### Testing

# %%
test_file = '/home/hackathon/other/hackathon_test_set_tabular_2_wo_out.xlsx'

testing = pd.io.excel.read_excel(test_file, keep_default_na=False)

sentences = defaultdict(list)
xls_len = len(testing.index)
newdat = zip([testing['doc_num'][x] for x in range(xls_len)], [testing['sentence_num'][x] for x in range(xls_len)], [testing['unique_tok_id'][x] for x in range(xls_len)], [testing['word'][x] for x in range(xls_len)])

for x, y, z, v in newdat:
    sentences[y].append(v)
    
final_testing_data = []
for x in range(1, len(sentences)+1):
    final_testing_data.append(sentences[x])
    
final_testing_data
# Out:
# [["SO'd", 'ib101'],
#  ['r', '-', 'PC(Lte31'],
#  ['-', 'J4i', '(', 'UCAA', '-', 'A', '--', 'C', ')', 'W'],
#  ['(', '-1', '-', 'c'],
#  ['I', 'V11117'],
#  ['10'],
#  ['1e', '1'],
#  ['I', 'NOTICE', 'TO', 'PAY', 'RENT', 'OR', 'QUIT', 'NOTICE'],
#  ['TO', ':'],
#  ['SHERNICE',
#   'MUNDELL',
#   ',',
#   'TENANT',
#   'in',
#   'possession',
#   'and',
#   'all',
#   'others',
#   ':'],
#  ['TAKE', 'NOTICE', 'THAT', ':'],
#  ['1', '.'],
#  ['Pursuant',
#   'to',
#   'a',
#   'written',
#   'lease',
#   'dated',
#   'August',
#   '1',
#   ',',
#   '2018',
#   'you',
#   'are',
#   'obligated',
#   'to',
#   'pay',
#   'certain',
#   'rents',
#   'on',
#   'the',
#   'premises',
#   'described',
#   'as',
#   ':',
#   '1311',
#   'CHARLESTOWN',
#   'DR',
#   '(',
#   'the',
#   '"',
#   'Premises',
#   '"',
#   ')',
#   ',',
#   'of',
#   'which',
#   'you',
#   'now',
#   'hold',
#   'possession',
#   '.'],
#  ['2', '.'],
#  ['You',
#   'are',
#   'late',
#   'in',
#   'the',
#   'payment',
#   'of',
#   'rents',
#   'totaling',
#   '$',
#   '3',
#   ',',
#   '500.00',
#   '.'],
#  ['This',
#   'rent',
#   'was',
#   'due',
#   'on',
#   'January',
#   '1',
#   ',',
#   '2019',
#   'and',
#   'relates',
#   'to',
#   '$',
#   '3500',
#   'for',
#   'the',
#   'months',
#   'of',
#   'January',
#   'and',
#   'February',
#   '2019',
#   '.'],
#  ['3', '.'],
#  ['You',
#   'are',
#   'hereby',
#   'required',
#   'to',
#   'PAY',
#   'the',
#   'said',
#   'rents',
#   ',',
#   'in',
#   'full',
#   ',',
#   'to',
#   'the',
#   'landlord',
#   ',',
#   'or',
#   'its',
#   'agents',
#   ',',
#   'within',
#   '7',
#   'days',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['4', '.'],
#  ['If',
#   'you',
#   'fail',
#   'to',
#   'pay',
#   'the',
#   'above',
#   'mentioned',
#   'rent',
#   'within',
#   'the',
#   'time',
#   'period',
#   'mentioned',
#   'aboye',
#   'the',
#   'tenant',
#   '&',
#   'will',
#   'be',
#   'forfeited',
#   'at',
#   'the',
#   'end',
#   'of',
#   'that',
#   'said',
#   'time',
#   'period',
#   'and',
#   'you',
#   'must',
#   'vacatifln',
#   'surrender',
#   'the',
#   'Premises',
#   'to',
#   'the',
#   'Landlord',
#   'by',
#   '12',
#   'noon',
#   'on',
#   'Mattlitr201E'],
#  ['THIS', 'NOTICE', 'TO', 'PAY', 'RENT'],
#  ['IS', 'GIVEN', 'PURSUANT', 'TO', 'THE', 'APPLICABLE', 'LAWS', 'OP'],
#  ['THE', 'STATE', 'OF', 'MARYLAND'],
#  ['AND',
#   'IN',
#   'NO',
#   'WAY',
#   'IMPAIRS',
#   'OR',
#   'LIMITS',
#   'ANY',
#   'OF',
#   'THE',
#   'OTHER',
#   'REMEDIES',
#   'OR',
#   'RIGHTS'],
#  ['THAT',
#   'THE',
#   'LANDLORD',
#   'MAY',
#   'HAVE',
#   'UNDER',
#   'THE',
#   'LEASE',
#   'OR',
#   'UNDER'],
#  ['THE', 'SAID', 'LAWS', '.'],
#  ['h', 'dayAof'],
#  ['Febru', '/', '2019'],
#  ['raw', 'n'],
#  ['it'],
#  ['i', 't'],
#  ['8041'],
#  ['Del', 'Haven', 'Road', 'Dundalk', 'MD', '21222'],
#  ['Landlord', "'s", 'Name', ':'],
#  ['eta', 'Sheely'],
#  ['Contact', 'Address'],
#  ['Page', '1', 'of', 'I', '02002', '-', '2019', 'LawDepacome'],
#  ['SO', '/', "SO'd"],
#  ['6SE172260T17'],
#  ['6SZ172260T17'],
#  ['617', ':', 'LO', '6TOZ', '-', '-', '10', '-', 'didW'],
#  ['LANDLORD', "'S", 'FIVE', 'DAY'],
#  ['NOTICE'],
#  ['STATE', 'OF', 'ILLINOIS', ')'],
#  ['Thornton', 'Management', ')'],
#  ['SS', '.'],
#  ['COUNTY', 'OF', 'COOK', '1'],
#  ['To', ':'],
#  ['Cierra', 'Cooper'],
#  ['YOU',
#   'ARE',
#   'HEREBY',
#   'NOTIFIED',
#   'that',
#   'there',
#   'is',
#   'now',
#   'due',
#   'the',
#   'undersigned',
#   'Landlord',
#   ',',
#   'the',
#   'sum',
#   'of',
#   '$',
#   '890.00',
#   'being',
#   'rent',
#   'for',
#   'the',
#   'premises',
#   'situated',
#   'in',
#   'the',
#   'City',
#   'of',
#   'Chicago',
#   'and',
#   'County',
#   'of',
#   'Cook',
#   ',',
#   'State',
#   'of',
#   'Illinois',
#   'and',
#   'described',
#   'as',
#   'follows',
#   ',',
#   'to',
#   'wit',
#   ':'],
#  ['The',
#   'property',
#   'at',
#   '8222',
#   'S',
#   'Carpenter',
#   'St',
#   ',',
#   'City',
#   'of',
#   'Chicago',
#   ',',
#   'Illinois',
#   ',',
#   '60620',
#   ',',
#   'together',
#   'with',
#   'all',
#   'buildings',
#   ',',
#   'sheds',
#   ',',
#   'closets',
#   ',',
#   'out',
#   '-',
#   'buildings',
#   ',',
#   'garages',
#   'and',
#   'other',
#   'structures',
#   'used',
#   'in',
#   'connection',
#   'with',
#   'said',
#   'premises',
#   '.'],
#  ['YOU', 'ARE', 'FURTHER', 'NOTIFIED', 'that', 'payment', 'of', 'said', 'sum'],
#  ['so',
#   'due',
#   'has',
#   'been',
#   'and',
#   'is',
#   'hereby',
#   'demanded',
#   'of',
#   'you',
#   'and',
#   'that',
#   'UNLESS',
#   'PAYMENT',
#   'THERE',
#   'OF',
#   'IS',
#   'MADE',
#   'ON',
#   'OR',
#   'BEFORE',
#   'THE',
#   'EXPIRATION',
#   'OF',
#   'FIVE',
#   'DAYS',
#   'AFTER'],
#  ['THE', 'SERVICE', 'OF', 'THIS', 'NOTICE'],
#  [',',
#   'YOUR',
#   'LEASE',
#   'OF',
#   'SAID',
#   'PREMISES',
#   'WILL',
#   'BE',
#   'TERMINATED',
#   'FIVE',
#   'DAYS'],
#  ['AFTER', 'SERVICE', 'OF', 'THIS', 'NOTICE', '.'],
#  ['ONLY',
#   'FULL',
#   'PAYMENT',
#   'of',
#   'the',
#   'rent',
#   'demanded',
#   'in',
#   'this',
#   'notice',
#   'will',
#   'waive',
#   'the',
#   'Landlord',
#   "'s",
#   'right',
#   'to',
#   'terminate',
#   'the',
#   'lease',
#   'under',
#   'this',
#   'Notice',
#   ',',
#   'unless',
#   'the',
#   'Landlord',
#   'agrees',
#   'in',
#   'writing',
#   'to',
#   'continue',
#   'the',
#   'lease',
#   'in',
#   'exchange',
#   'for',
#   'receiving',
#   'partial',
#   'payment',
#   '.'],
#  ['Dated', 'this', 'April', 'day', 'of', '8th', '2019', '.'],
#  ['LANDLORD',
#   'OR',
#   'LANDLORD',
#   "'S",
#   'AGENT',
#   'MANAGEMENT',
#   '8222',
#   'S',
#   'CARPENTER',
#   'ST',
#   'CHICAGO',
#   'IL',
#   ',',
#   '60620'],
#  ['C', 'r', 'cry', '-', 'a', 'CoopeK'],
#  ['12e', '-', 'ciuc', ',', 's4', '-', 'Th', '-', 'auan'],
#  ['I', 'Oct', 't', 'trn'],
#  ['C', '-', 'i2'],
#  ['Cep', "'", 'zat', '5', '-', '000', 'M', ')', 'ig', '33', '7591'],
#  ['WELLS', 'FARG', '0', 'Customer', 'service'],
#  ['March', '26', ',', '2019'],
#  ['Online', ':'],
#  ['wellsfargo.com'],
#  ['Telephone', ':'],
#  ['1', '-', '800', '-', '416', '-', '1472', 'ADRIAN', 'S', 'ESPARZA'],
#  ['Hours', ':'],
#  ['Moody', 'through', 'Friday', ':', '7', ':', 'oo', 'am', '-', 'to'],
#  ['Loam', 'pm', '.'],
#  ['7939', 'WILLIAM', 'GRV'],
#  ['SAN', 'ANTONIO', ',', 'TX', '78254', '-', '6095'],
#  ['Saturday', ':', '7:00', 'a.m.', 'to', '5:00', 'pin', '.'],
#  ['Centeal', 'Time'],
#  ['Correspondence', ':'],
#  ['P.O.', 'Box', '10335'],
#  ['Des', 'Moines', ',', 'IA', '50306'],
#  ['Account', 'information'],
#  ['Loan', 'number', ':'],
#  ['0373672963'],
#  ['Property', 'address', ':', '7939'],
#  ['WILI1AM', 'GRV', 'SAN'],
#  ['*'],
#  ['TOMO', ',', 'TX', '78254', '-', '6095'],
#  ['First', 'missed', 'payment', 'date', ':', 'February', '1', ',', '2019'],
#  ['Number', 'of', 'days', 'past', 'due', ':'],
#  ['53', 'Subject', ':', 'Notice', 'of', 'default'],
#  ['inunediate', 'action', 'is', 'needed'],
#  ['Dear', 'ADRIAN', 'S', 'ESPARZA', ':'],
#  ['Your',
#   'loan',
#   'is',
#   'in',
#   'default',
#   'because',
#   'you',
#   'have',
#   'not',
#   'made',
#   'the',
#   'required',
#   'payments',
#   'due',
#   '.'],
#  ['In',
#   'this',
#   'letter',
#   'you',
#   "'ll",
#   'find',
#   'important',
#   'information',
#   'about',
#   'this',
#   'default',
#   'and',
#   'the',
#   'steps',
#   'needed',
#   'to',
#   'bring',
#   'your',
#   'account',
#   'current',
#   '.'],
#  ['We',
#   "'re",
#   'required',
#   'to',
#   'provide',
#   'you',
#   'with',
#   'this',
#   'important',
#   'notice',
#   'per',
#   'the',
#   'terms',
#   'of',
#   'your',
#   'mortgage',
#   'or',
#   'deed',
#   'of',
#   'trust',
#   'and/or',
#   'state',
#   'law',
#   '.'],
#  ['What',
#   'you',
#   'need',
#   'to',
#   'know',
#   'To',
#   'cure',
#   'this',
#   'loan',
#   'default',
#   ',',
#   'you',
#   '"',
#   'need',
#   'to',
#   'pay',
#   'the',
#   'total',
#   'past',
#   'due',
#   'amount',
#   'listed',
#   'below',
#   'on',
#   'or',
#   'before',
#   'May',
#   '2',
#   ',',
#   '2019',
#   ','],
#  ['If',
#   'we',
#   'do',
#   "n't",
#   'receive',
#   'the',
#   'payment',
#   'on',
#   'or',
#   'before',
#   'May',
#   '2',
#   ',',
#   '2019',
#   ',',
#   'we',
#   'will',
#   'require',
#   'the',
#   'immediate',
#   'payment',
#   'of',
#   'your',
#   'loan',
#   'in',
#   'full',
#   '.'],
#  ['This', 'is', 'called', '"', 'accelerating', '"', 'your', 'loan', '.'],
#  ['We',
#   'may',
#   'also',
#   'take',
#   'other',
#   'steps',
#   'allowed',
#   'by',
#   'your',
#   'mortgage',
#   'or',
#   'deed',
#   'of',
#   'trust',
#   'and/or',
#   'state',
#   'law',
#   ',',
#   'including',
#   'foreclosure',
#   '.'],
#  ['Here',
#   'are',
#   'the',
#   'details',
#   'of',
#   'the',
#   'past',
#   'due',
#   'payments',
#   ',',
#   'as',
#   'of',
#   'March',
#   '25',
#   ',',
#   '2019',
#   ':'],
#  ['Past', 'Due', 'Payment', 'Amount', ':', '$', '3', ',', '073.32'],
#  ['Late', 'Charge', 'Balance', ':', '$', '3', ',', '155.31'],
#  ['Other', 'Fees', 'and', 'costs', ':'],
#  ['$', 'o_oo'],
#  ['Total_past', 'due', 'amount', ':', '$', '6', ',', '228.63'],
#  ['T', "'"],
#  ['Os', '5000', 'oOZ'],
#  ['(', '01.s(o'],
#  ['o'],
#  ['THREE', '(', '3', ')', 'DAY', 'NOTICE'],
#  ['TO', 'PAY', 'RENT', 'OR'],
#  ['QUIT', 'e'],
#  ['PPiah.1.77', '-', '2.12', 'Lamilsulsom'],
#  ['REQUIRED'],
#  ['TO', ':'],
#  ['Oscar', 'Trigueros', 'possession', ')'],
#  ['Snow'],
#  ['*', 'any', 'and', 'AU', '.'],
#  ['known',
#   'names',
#   'of',
#   'TENANT(8',
#   ')',
#   ',',
#   'subtonente',
#   'and',
#   'all',
#   'others'],
#  ['In', 'AND', 'to', 'ANY', 'AND', 'AU', '.'],
#  ['OTHER', 'cow', '/', 'Aims', ')', ',', 'INCLUDING', "'", 'mumuurrzo'],
#  ['To',
#   'Does',
#   'mnouen',
#   'Q.',
#   'INCLUSIVE',
#   'Address',
#   'of',
#   'Premises',
#   ':',
#   '1',
#   '2016',
#   's.',
#   'Shenandoah',
#   'St'],
#  ['1'],
#  ['*', 'Apt', '.'],
#  ['No', '.', '1', '108'],
#  ['1', 'REQUIRED', ','],
#  ['If',
#   'Applicable',
#   '90034',
#   ',',
#   'California',
#   ',',
#   'ZIP',
#   ':',
#   'Pursuant',
#   'to',
#   'Section',
#   '1161(2',
#   ')',
#   'of',
#   'the',
#   'California',
#   'Code',
#   'of',
#   'Civil',
#   'Procedure',
#   'NOTICE',
#   'IS',
#   'HERESY',
#   'GIVEN',
#   'that',
#   'within',
#   'THREE',
#   '(',
#   '3',
#   ')',
#   'DAYS',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   'upon',
#   'you',
#   ',',
#   'you',
#   'are',
#   'required',
#   'to',
#   'deliver',
#   'up',
#   'possession',
#   'of',
#   'the',
#   'above',
#   'described',
#   'premises',
#   'to',
#   'the',
#   'undersigned',
#   'Owner',
#   '/',
#   'Agent',
#   'or',
#   'pay',
#   'the',
#   'total',
#   'sum',
#   'of',
#   '1'],
#  ['s000'],
#  ['I', 'Nesausuo', '(', 'rent', ')'],
#  ['to',
#   'the',
#   'undersigned',
#   'Owner',
#   '/',
#   'Agent',
#   'of',
#   'the',
#   'premises',
#   '.'],
#  ['The',
#   'sum',
#   'you',
#   'are',
#   'required',
#   'to',
#   'pay',
#   'Is',
#   'for',
#   'the',
#   'rent',
#   'due',
#   'and',
#   'unpaid',
#   'as',
#   'follows',
#   ';'],
#  ['*'],
#  ['I1650.00', 'for', 'the', 'pedal'],
#  ['I', 'Nov.', '2018'],
#  ['*', 'through', 'Dec.', '2019'],
#  ['REQUIRED'],
#  ['$'],
#  ['1650.00', 'Jan.', '2019'],
#  ['Feb.', '2019'],
#  ['for', 'the', 'period', 'through', '$'],
#  ['1650.00'],
#  ['for', 'the', 'period', 'Feb.', '2019', 'through', 'Mar.2019'],
#  ['Unless',
#   'you',
#   'have',
#   'paid',
#   'the',
#   'full',
#   'amount',
#   'enumerated',
#   'above',
#   'or',
#   'vacated',
#   'and',
#   'delivered',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   'within',
#   'THREE',
#   '(',
#   '3',
#   ')'],
#  ['DAYS',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   'on',
#   'you',
#   ',',
#   'an',
#   'action',
#   'in',
#   'UNLAWFUL',
#   'DETAINER',
#   'will',
#   'be',
#   'instituted',
#   'against',
#   'you',
#   'to',
#   'recover',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   'and',
#   'to',
#   'have',
#   'the',
#   'rental',
#   '/',
#   'lease',
#   'agreement',
#   'under',
#   'which',
#   'you',
#   'hold',
#   'the',
#   'premises',
#   'forfeited',
#   'and',
#   'to',
#   'recover',
#   'rents',
#   'and',
#   'statutory',
#   'penalties',
#   'together',
#   'with',
#   'court',
#   'costs',
#   'and',
#   'attorney',
#   'fees',
#   '.'],
#  ['This', 'Notice', 'supersedes', 'any', 'and', 'all', 'previous'],
#  ['Three', 'Day', 'Notices', 'to', 'Pay', 'Rent', 'or', 'Quit', '.'],
#  ['El',
#   'RENT',
#   'payment',
#   'must',
#   'be',
#   'made',
#   'PAYABLE',
#   'to',
#   'the',
#   'following',
#   'Owner',
#   '/',
#   'Agent',
#   ';',
#   '(',
#   'name',
#   ')',
#   ';',
#   'Fred',
#   'Leeds',
#   'Properties'],
#  ['*', 'REQUIRED'],
#  ['Irma', 'Gomez', ',', 'and', 'at', 'the', 'following', 'ADDRESS', ';'],
#  ['*', 'I', '2016', 's.'],
#  ['Shenandoah', 'sit', 'II', ';'],
#  ['Suite:4100'],
#  ['I', 'REQUIRED', ','],
#  ['ft', '_'],
#  ['1Appicable'],
#  ['City', ':', 'Los', 'Angeles'],
#  ['LA', ',', 'ZIP', ':', '90034', 'and'],
#  ['Tel', 'No', '.'],
#  ['Is', ':', 'I', '(', '3b0', ')', '351', '-', '4963'],
#  ['*', 'REQUIRED'],
#  ['Cl', 'Rent', 'Payment'],
#  ['By', 'MAIL'],
#  ['ONLY', '(', 'i.e.', ',', 'P.O.', 'Box', 'written', 'above', ')', '.'],
#  ['IF',
#   'RENT',
#   'PAYMENT',
#   'CAN',
#   'BE',
#   'PAID',
#   'IN',
#   'PERSON',
#   '(',
#   'to',
#   'above',
#   'address',
#   ')',
#   ',',
#   'said',
#   'payment',
#   'may',
#   'be',
#   'delivered',
#   'to',
#   'Ovmer',
#   '/',
#   'Agent',
#   'between',
#   'the',
#   'HOURS',
#   'of',
#   'REQUIRED',
#   '.'],
#  ['IF',
#   'Rent',
#   'payment',
#   'can',
#   'be',
#   'MADE',
#   'IN',
#   'PERSON',
#   ')',
#   '0',
#   '8:30',
#   'A.M.',
#   'to',
#   '5:00',
#   'P.M.',
#   ',',
#   'OR',
#   '0',
#   'and'],
#  ['on',
#   'the',
#   'following',
#   'DAYS',
#   'of',
#   'the',
#   'week',
#   '(',
#   'check',
#   'one',
#   ')',
#   ';'],
#  ['(', 'Chock', 'ONE', 'Applicable', 'Sox', 'and', 'or', 'Type', 'in'],
#  ['Applicable', 'Han', 'c', 'the', 'lby(s', ')'],
#  ['Rent', 'Can', 'Se', 'Paid', ')', '0'],
#  ['Monday', 'through', 'Friday', ',', 'OR', '0'],
#  ['REQUIRED', '-', 'IF', 'Rent', 'moment', 'can', 'be'],
#  ['(',
#   'Check',
#   'ONE',
#   'Applicable',
#   'Sac',
#   'end',
#   'or',
#   'Type',
#   'in',
#   'Apo',
#   '/',
#   'Sable',
#   'Day(e',
#   ')',
#   'of',
#   'Week',
#   'Rent',
#   'Cull',
#   '.'],
#  ['PAW'],
#  ['MADE', 'IN', 'PERSON', ')', '0'],
#  ['Wan',
#   'electronic',
#   'funds',
#   'transfer',
#   'has',
#   'been',
#   'previously',
#   'established',
#   ',',
#   'payment',
#   'may',
#   'be',
#   'made',
#   'pursuant',
#   'to',
#   'that',
#   'prOcedure',
#   '.'],
#  ['REQUIRED'],
#  ['DATED', ':', '02', '/', '28', '/', '2019'],
#  ['LANDLORD',
#   '/',
#   'MANAGER',
#   ':',
#   '(',
#   'Signature',
#   'of',
#   'Landlord',
#   '/',
#   'Agent',
#   ')',
#   'Copmfght1e77.2012',
#   'L'],
#  ['Icdcem'],
#  ['Mortgage', 'Servicing'],
#  ['1Corporate', 'Drive', ',', 'Suite', '360'],
#  ['nusEnDA', 'CREDIT', 'UNION'],
#  ['a'],
#  ['Lake', 'Zurich', ',', 'IL', '6009', '-', '8945'],
#  ['Cust', '.'],
#  ['Sem', '877427', '-', '0550', '1', '-', '2rWc', ','],
#  ['\\ZO'],
#  ['Fax', '847', '-', '574', '-', '7659', 'www.nusenda.org'],
#  ['SOCDsco', '-', 'r4', 'V16539', '.'],
#  ['August', '02', ',', '2018'],
#  ['FIRST', 'CLASS', 'MAIL'],
#  ['MS1770'],
#  ['Kristeena', 'Romero'],
#  ['3805', 'Garcia', 'St', 'NE', 'Albuquerque', 'NM', '87111', '-'],
#  ['Loan', 'Number', ':', '1452760679'],
#  ['Description', 'of', 'Mortgaged', 'Property', ':'],
#  ['3805', 'Garcia', 'St', 'NE', 'Albuquerque', 'NM', '87111'],
#  ['THIS',
#   'DOCUMENT',
#   'IS',
#   'AN',
#   'ATTEMPT',
#   'TO',
#   'COLLECT',
#   'A',
#   'DEBT',
#   ',',
#   'AND',
#   'ANY',
#   'INFORMATION'],
#  ['OBTAINED'],
#  ['WILL', 'BE', 'USED', 'FOR', 'THAT', 'PURPOSE', '.'],
#  ['IF', 'YOU', 'ARE', 'IN', 'BANKRUPTCY', 'OR'],
#  ['HAVE',
#   'BEEN',
#   'DISCHARGED',
#   'IN',
#   'BANKRUPTCY',
#   ',',
#   'THIS',
#   'LETTER',
#   'IS',
#   'FOR',
#   'INFORMATIONAL',
#   'PURPOSES'],
#  ['ONLY'],
#  ['AND',
#   'DOES',
#   'NOT',
#   'CONSTITUTE',
#   'A',
#   'DEMAND',
#   'FOR',
#   'PAYMENT',
#   'IN',
#   'VIOLATION',
#   'OF',
#   'THE'],
#  ['AUTOMATIC', 'STAY', 'OR'],
#  ['THE',
#   'DISCHARGE',
#   'INJUNCTION',
#   'OR',
#   'AN',
#   'ATTEMPT',
#   'TO',
#   'RECOVER',
#   'ALL',
#   'OR'],
#  ['ANY', 'PORTION', 'OF', 'THE', 'DEBT', 'FROM', 'YOU'],
#  ['PERSONALLY', '.'],
#  ['Notice', 'of', 'Acceleration'],
#  ['Dear', 'Kristeena', 'Romero', ':'],
#  ['PLEASE',
#   'TAKE',
#   'NOTICE',
#   ',',
#   'as',
#   'a',
#   'result',
#   'of',
#   'your',
#   'failure',
#   'tc',
#   'cure',
#   'the',
#   'default',
#   'on',
#   'the',
#   'Note',
#   'that',
#   'is',
#   'secured',
#   'by',
#   'a',
#   'Mortgage',
#   'or',
#   'Deed',
#   'of',
#   'Trust',
#   ',',
#   'as',
#   'applicable',
#   '(',
#   'Security',
#   'Instrument',
#   ')',
#   'the',
#   'entire',
#   'amount',
#   'of',
#   'the',
#   'outstanding',
#   'balance',
#   'of',
#   'principal',
#   'and',
#   'interest',
#   'of',
#   'the',
#   'Note',
#   'has',
#   'been',
#   ',',
#   'and',
#   'is',
#   'hereby',
#   ',',
#   'declared',
#   'accelerated',
#   'and',
#   'immediately',
#   'due',
#   'and',
#   'payable',
#   '.'],
#  ['Demand',
#   'is',
#   'hereby',
#   'made',
#   'for',
#   'the',
#   'immediate',
#   'payment',
#   'of',
#   'the',
#   'total',
#   'principal',
#   'balance',
#   'plus',
#   'interest',
#   ',',
#   'costs',
#   'and',
#   'fees',
#   ',',
#   'and',
#   'advances',
#   'if',
#   'any',
#   'as',
#   'of',
#   'the',
#   'date',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['The',
#   'amount',
#   'owed',
#   'as',
#   'of',
#   'the',
#   'date',
#   'of',
#   'this',
#   'letter',
#   'is',
#   '$',
#   '124',
#   ',',
#   '061.92',
#   'plus',
#   'unpaid',
#   'interest',
#   'that',
#   'has',
#   'accrued',
#   'since',
#   'the',
#   'date',
#   'of',
#   'default',
#   '(',
#   '"',
#   'Accelerated',
#   'Amount',
#   '"',
#   ')',
#   '.'],
#  ['2', '.'],
#  ['You',
#   'may',
#   'have',
#   'the',
#   'right',
#   ',',
#   'by',
#   'law',
#   'and/or',
#   'through',
#   'your',
#   'Security',
#   'Instrument',
#   'and',
#   'Note',
#   ',',
#   'to',
#   'reinstate',
#   'your',
#   'loan',
#   'after',
#   'acceleration',
#   '.'],
#  ['The',
#   'Reinstatement',
#   'Amount',
#   'is',
#   'the',
#   'sum',
#   'of',
#   'a',
#   ')',
#   'the',
#   'amount',
#   'which',
#   'is',
#   'due',
#   'under',
#   'the',
#   'Security',
#   'Instrument',
#   'and',
#   'Note',
#   'as',
#   'if',
#   'no',
#   'acceleration',
#   'has',
#   'occurred',
#   ';',
#   'and',
#   'b',
#   ')',
#   'expenses',
#   'incurred',
#   'in',
#   'enforcing',
#   'the',
#   'Security',
#   'Instrument',
#   'and',
#   'the',
#   'Note',
#   ',',
#   'which',
#   'includes',
#   ',',
#   'but',
#   'is',
#   'not',
#   'limited',
#   'to',
#   ',',
#   'attorney',
#   'fees',
#   '.'],
#  ['As',
#   'of',
#   'the',
#   'date',
#   'of',
#   'this',
#   'notice',
#   'the',
#   'Reinstatement',
#   'Amount',
#   'is',
#   '$',
#   '4',
#   ',',
#   '620.28',
#   '.'],
#  ['3', '.'],
#  ['Interest',
#   'and',
#   'other',
#   'charges',
#   'may',
#   'vary',
#   'from',
#   'day',
#   'to',
#   'day',
#   'and',
#   'will',
#   'continue',
#   'to',
#   'accrue',
#   ';',
#   'therefore',
#   ',',
#   'the',
#   'Accelerated',
#   'Amount',
#   'and',
#   ',',
#   'if',
#   'applicable',
#   ',',
#   'Reinstatement',
#   'Amount',
#   'may',
#   'be',
#   'greater',
#   'after',
#   'the',
#   'date',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['To',
#   'obtain',
#   'additional',
#   'information',
#   'or',
#   'updated',
#   'figures',
#   'for',
#   'the',
#   'Accelerated',
#   'Amount',
#   'and',
#   ',',
#   'if',
#   'applicable',
#   ',',
#   'Reinstatement',
#   'Amount',
#   ',',
#   'please',
#   'contact',
#   'us',
#   'at',
#   '1',
#   '-',
#   '877',
#   '-',
#   '827',
#   '-',
#   '0558',
#   '.'],
#  ['LM683'],
#  ['/', 'BJ7'],
#  ['Mortgage', 'Servicing'],
#  ['1',
#   'Corporate',
#   'Drive',
#   ',',
#   'Suite',
#   '360',
#   'nusEnDne',
#   'CREDIT',
#   'UNION'],
#  ['Lake', 'Zurich', ',', 'IL', '60047', '-', "89'15"],
#  ['Cust', '.'],
#  ['Serv', '.'],
#  ['877',
#   '-',
#   '827',
#   '-',
#   '0554',
#   'Fax',
#   '847',
#   '-',
#   "57'1",
#   '-',
#   '7659',
#   'www.nusenda.org'],
#  ['jOYT'],
#  ['14Id'],
#  ['E6'],
#  ['Page', '2', 'of', '2', 'August', '02', ',', '2018'],
#  ['Loan', 'Number', ':', '1452760679', '4', '.'],
#  ['Since',
#   'you',
#   'have',
#   'failed',
#   'to',
#   'cure',
#   'the',
#   'default',
#   ',',
#   'we',
#   'are',
#   'proceeding',
#   'with',
#   'foreclosure',
#   'by',
#   'either',
#   'non',
#   '-',
#   'judicial',
#   'proceeding',
#   'or',
#   'foreclosure',
#   'by',
#   'judicial',
#   'proceeding',
#   'as',
#   'applicable',
#   ',',
#   'and',
#   'the',
#   'sale',
#   'of',
#   'the',
#   'Property',
#   ',',
#   'in',
#   'which',
#   'we',
#   'shall',
#   'be',
#   'entitled',
#   'to',
#   'collect',
#   'all',
#   'expenses',
#   'incurred',
#   'in',
#   'pursuing',
#   'the',
#   'remedies',
#   'available',
#   'to',
#   'us',
#   'including',
#   ',',
#   'but',
#   'not',
#   'limited',
#   'to',
#   ',',
#   'attorney',
#   "'s",
#   'fees',
#   'and',
#   'any',
#   'other',
#   'remedies',
#   'provided',
#   'in',
#   'the',
#   'Note',
#   ',',
#   'Security',
#   'Instrument',
#   ',',
#   'and',
#   'applicable',
#   'Federal',
#   'and',
#   'State',
#   'laws',
#   '.'],
#  ['If',
#   'you',
#   'have',
#   'recently',
#   'submitted',
#   'a',
#   'loss',
#   'mitigation',
#   'application',
#   'please',
#   'see',
#   'paragraph',
#   '9',
#   'below',
#   '.'],
#  ['5', '.'],
#  ['If',
#   'you',
#   'make',
#   'a',
#   'payment',
#   'that',
#   'is',
#   'less',
#   'than',
#   'the',
#   'Accelerated',
#   'Amount',
#   'or',
#   ',',
#   'if',
#   'applicable',
#   ',',
#   'less',
#   'than',
#   'the',
#   'Reinstatement',
#   'Amount',
#   ',',
#   'we',
#   'may',
#   'credit',
#   'your',
#   'payment',
#   'to',
#   'your',
#   'account',
#   'or',
#   'place',
#   'the',
#   'monies',
#   'in',
#   'a',
#   'suspense',
#   'account',
#   'and',
#   'continue',
#   'to',
#   'either',
#   'refer',
#   'the',
#   'loan',
#   'to',
#   'counsel',
#   'to',
#   'foreclose'],
#  ['or',
#   ',',
#   'if',
#   'the',
#   'loan',
#   'has',
#   'been',
#   'already',
#   'referred',
#   'to',
#   'counsel',
#   ',',
#   'continue',
#   'with',
#   'the',
#   'foreclosure',
#   '.'],
#  ['The',
#   'application',
#   'of',
#   'the',
#   'payments',
#   'to',
#   'your',
#   'account',
#   'is',
#   'not',
#   'to',
#   'be',
#   'construed',
#   'as',
#   'waiving',
#   'or',
#   'modifying',
#   'any',
#   'of',
#   'the',
#   'rights',
#   'or',
#   'remedies',
#   'of',
#   'that',
#   'of',
#   'the',
#   'Beneficiary',
#   '/',
#   'Mortgagee',
#   '.'],
#  ['6', '.'],
#  ['Payment',
#   'must',
#   'be',
#   'in',
#   'cashier',
#   "'s",
#   'check',
#   ',',
#   'certified',
#   'check',
#   ',',
#   'or',
#   'money',
#   'order',
#   'and',
#   'payable',
#   'to',
#   'us',
#   'at',
#   'the',
#   'address',
#   'stated',
#   'below',
#   '.'],
#  ['Please',
#   'include',
#   'your',
#   'loan',
#   'number',
#   'on',
#   'any',
#   'payment',
#   'or',
#   'correspondence',
#   '.'],
#  ['Payment',
#   'shall',
#   'be',
#   'made',
#   'to',
#   'the',
#   'Beneficiary',
#   '/',
#   'Mortgagee',
#   'at',
#   ':'],
#  ['Nusenda',
#   'Credit',
#   'Union',
#   '1',
#   'Corporate',
#   'Drive',
#   ',',
#   'Suite',
#   '360'],
#  ['Lake', 'Zurich', ',', 'IL', '60047', '-', '8945', '7', '.'],
#  ['Nothing',
#   'in',
#   'this',
#   'Notice',
#   'is',
#   'intended',
#   'to',
#   'waive',
#   'or',
#   'modify',
#   'any',
#   'rights',
#   'or',
#   'remedies',
#   'of',
#   'the',
#   'Beneficiary',
#   '/',
#   'Mortgagee',
#   '.'],
#  ['8', '.'],
#  ['If',
#   'you',
#   'disagree',
#   'with',
#   'any',
#   'portion',
#   'of',
#   'this',
#   'Notice',
#   'of',
#   'Acceleration',
#   'you',
#   'may',
#   'contact',
#   'us',
#   'at',
#   '1',
#   '-',
#   '877',
#   '-',
#   '827',
#   '-',
#   '0558',
#   '.'],
#  ['9', '.'],
#  ['If',
#   'you',
#   'have',
#   'submitted',
#   'a',
#   'complete',
#   'Borrower',
#   'response',
#   'package',
#   'and',
#   'your',
#   'loan',
#   'is',
#   'being',
#   'considered',
#   'for',
#   'Loss',
#   'Mitigation',
#   'this',
#   'does',
#   'not',
#   'affect',
#   'the',
#   'Loss',
#   'Mitigation',
#   'process',
#   'and',
#   'we',
#   'will',
#   'not',
#   'proceed',
#   'with',
#   'the',
#   'foreclosure',
#   'process',
#   'unless',
#   'your',
#   'application',
#   'is',
#   'denied',
#   'and',
#   'any',
#   'applicable',
#   'appeal',
#   'period',
#   'has',
#   'expired',
#   '.'],
#  ['If',
#   'you',
#   'have',
#   'any',
#   'questions',
#   ',',
#   'please',
#   'call',
#   'the',
#   'Loss',
#   'Mitigation',
#   'Department',
#   'at',
#   '1',
#   '-',
#   '888',
#   '-',
#   '395',
#   '-',
#   '3997',
#   ',',
#   'Monday',
#   'through',
#   'Friday',
#   ',',
#   '8:00',
#   'a.m.',
#   'to',
#   '5:00',
#   'p.m.',
#   ',',
#   'CST',
#   '.'],
#  ['Sincerely', ',', 'Loan', 'Servicing'],
#  ['LM683'],
#  ['/', 'BJ7'],
#  ['TO', 'PAY', 'RENT', 'OR', 'VACATE', 'PREMISES', 'Resident', 'Name', ':'],
#  ['Latia', 'Ray', 'Premises', ':'],
#  ['7171', 'Marshall', 'Ave', 'SE', '205', '98092'],
#  ['You',
#   'are',
#   'hereby',
#   'notified',
#   'that',
#   'you',
#   'are',
#   'in',
#   'default',
#   'your',
#   'lease',
#   'agreement',
#   'for',
#   'the',
#   'above',
#   '-',
#   'described',
#   'premises'],
#  ['(',
#   'the',
#   '"',
#   'Premises',
#   '"',
#   ')',
#   'for',
#   'failure',
#   'to',
#   'pay',
#   'rent',
#   ';',
#   'additional',
#   'rent',
#   ',',
#   'and/or',
#   'other',
#   'charges',
#   'as',
#   'required',
#   'in',
#   'your',
#   'lease',
#   ',',
#   'and',
#   'in',
#   'the',
#   'amounts',
#   'specified',
#   'herein',
#   '.'],
#  ['Pursuant',
#   'to',
#   'the',
#   'terms',
#   'of',
#   'your',
#   'lease',
#   'and',
#   'the',
#   'Washington',
#   'State',
#   'Landlord',
#   'Tenant',
#   'Act',
#   ',',
#   'section',
#   '3',
#   'of',
#   'the',
#   'Revised',
#   'code',
#   'of',
#   'Washington',
#   ',',
#   'Tarragon',
#   'Property',
#   'services',
#   "'",
#   'demands',
#   'payment',
#   'of',
#   'the',
#   'following',
#   'charge',
#   'or',
#   'that',
#   'you',
#   'surrender',
#   'the',
#   'three',
#   '(',
#   '3',
#   ')',
#   'date',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['If',
#   'you',
#   'fail',
#   'to',
#   'pay',
#   ',',
#   'in',
#   'full',
#   ',',
#   'the',
#   'amounts',
#   'herein',
#   'or',
#   'surrender',
#   'legal',
#   'proceeding',
#   'will',
#   'be',
#   'commence',
#   'you',
#   'for',
#   'unlawful',
#   'detainer',
#   'at',
#   'additional',
#   'cost',
#   'and',
#   'expense',
#   'to'],
#  ['you',
#   'including',
#   ',',
#   'but',
#   'not',
#   'limited',
#   'to',
#   ',',
#   'all',
#   'costs',
#   'and',
#   'reasonable',
#   'attorney',
#   'fees',
#   '.'],
#  ['irrent'],
#  ['Rent'],
#  ['Due',
#   'from',
#   ':',
#   '04',
#   '/',
#   '01',
#   '/',
#   '2019',
#   'to',
#   '04',
#   '/',
#   '30',
#   '/',
#   '2019'],
#  ['$', '1505.00', 'st'],
#  ['Due', 'Rent', 'from', ':', 'to', 'TOTAL', 'DUE', ':'],
#  ['$', '1505.00'],
#  ['ARRAGON', 'PROPERTY', 'SERVICES', '04'],
#  ['/', '01', '/', '2019', 'RTIFICATION', 'OF', 'SERVICE', ':'],
#  ['The',
#   'undersigned',
#   'hereby',
#   'certifies',
#   'that',
#   'this',
#   'notice',
#   'was',
#   'properly',
#   'served',
#   'upon',
#   'resident',
#   'named',
#   'herein',
#   'by',
#   '(',
#   'choose',
#   'one',
#   'of',
#   'the',
#   'following',
#   ')',
#   ':',
#   'Personally',
#   'delivering',
#   'this',
#   'notice',
#   'to',
#   'the',
#   'resident',
#   'named',
#   'herein',
#   ';',
#   'ersonally',
#   'delivering',
#   'this',
#   'notice',
#   'to',
#   'an',
#   'occupant',
#   'of',
#   'the',
#   'Premises',
#   'of',
#   'suitable',
#   'age',
#   'and',
#   'sending',
#   'a',
#   'copy',
#   'through',
#   'the',
#   'mail',
#   'addressed',
#   'to',
#   'the',
#   'resident',
#   'named',
#   'herein',
#   'at',
#   'his',
#   '/',
#   'her',
#   'place',
#   'of',
#   'residence',
#   ';',
#   'Depositing',
#   'this',
#   'notice',
#   'in',
#   'the',
#   'U.S.',
#   'Mail',
#   ',',
#   'regular',
#   'mail',
#   ',',
#   'postage',
#   'prepaid',
#   ',',
#   'addressed',
#   'to',
#   'the',
#   'resident',
#   'named',
#   'herein',
#   'at',
#   'the',
#   'Premises',
#   ',',
#   'and',
#   'posting',
#   'a',
#   'copy',
#   'of',
#   'this',
#   'notice',
#   'in',
#   'a',
#   'conspicuous',
#   'place',
#   'on',
#   'the',
#   'Premises',
#   '.'],
#  ['*', 'Must', 'be', 'paid', 'in', 'Full', 'with', 'Cashiers'],
#  ['check', '*', 'ite', 'Fees', 'Water', ',', 'Sewer', ','],
#  ['Trash', 'are', 'not', 'Included', 'In', 'balance', '!'],
#  ['Please', 'call', 'or', 'stop', 'by', 'leasing', 'office', 'today', '.'],
#  ['State',
#   'of',
#   'Colorado',
#   'Rev.',
#   '133E051',
#   '-',
#   'LEASE',
#   "'",
#   'AGREEMENT',
#   '-'],
#  ['-', 'Afhts', 'Lease', 'Agreement'],
#  ['(',
#   'this',
#   '"',
#   'Agreement',
#   '"',
#   ')',
#   'is',
#   'made',
#   'this',
#   '02',
#   'day',
#   'of',
#   'April',
#   ',',
#   '2018',
#   ',',
#   'by',
#   'and',
#   'among',
#   'JOYCE',
#   'LAWANSON',
#   '(',
#   '"',
#   'Landlord',
#   '"',
#   ')',
#   'and',
#   'MICHELLE',
#   'A',
#   '-',
#   'r'],
#  ['_'],
#  ['.E_', '-'],
#  ['_', '-'],
#  ['ERsc)N.'],
#  ['The',
#   'Tenant',
#   'is',
#   'severally',
#   'liable',
#   'to',
#   'Landlord',
#   'payment',
#   '-orrent',
#   'and',
#   "performance'in",
#   'accordance',
#   'with',
#   'all',
#   'other',
#   'terms',
#   'of',
#   'this',
#   'Agreement',
#   '.'],
#  ['Each',
#   'Landl',
#   'be',
#   'raferreci',
#   '-',
#   'to',
#   'indfiliduallY',
#   'ass',
#   '"',
#   'Party',
#   '"',
#   'and',
#   '.'],
#  ['collectively', 'as', 'the', '"', 'Parties', '.'],
#  ['"'],
#  ['-', '-', '-', '-', '-', '1', '.'],
#  ['Premises', '.'],
#  ['The',
#   'premises',
#   'leased',
#   'is',
#   'a',
#   'house',
#   'wIth',
#   'thr',
#   'edroom(s',
#   ')',
#   'and',
#   'two',
#   'and',
#   'five',
#   'tenths',
#   'bathroom(s',
#   ')',
#   'and',
#   'two',
#   '(',
#   '2',
#   ')',
#   'parking',
#   'space(s',
#   ')',
#   'locate',
#   'at',
#   '4414',
#   'WALDEN',
#   'ST',
#   ',',
#   'DENVER',
#   ',',
#   'CO',
#   '80249'],
#  ['"', 'Premises', '"', ')', '.'],
#  ['The',
#   'Premises',
#   'includes',
#   'the',
#   'followings',
#   'as',
#   'is',
#   'ocated',
#   'in',
#   'a',
#   'very',
#   'quiet',
#   'and',
#   'serene',
#   'neighborhood',
#   '.'],
#  ['Its',
#   'a',
#   'nice',
#   'area',
#   'to',
#   'raise',
#   'kids',
#   'and',
#   'the',
#   'property',
#   'is',
#   'fairly',
#   'new',
#   'was',
#   'built',
#   'in',
#   '2015',
#   '.'],
#  ['2', '.'],
#  ['Agreement', 'to', 'Lease', '.'],
#  ['Landlord',
#   'agrees',
#   'to',
#   'lease',
#   'to',
#   'Tenant',
#   'and',
#   'Tenant',
#   'agrees',
#   'to',
#   'lease',
#   'from',
#   'Landlord',
#   ',',
#   'according',
#   'to',
#   'the',
#   'terms',
#   'and',
#   'conditions',
#   'set',
#   'forth',
#   'herein',
#   ',',
#   'the',
#   'Premises',
#   '.'],
#  ['3', '.'],
#  ['Term', '.'],
#  ['This',
#   'Agreement',
#   'will',
#   'be',
#   'for',
#   'a',
#   'term',
#   'beginning',
#   'on',
#   'May',
#   '18',
#   ',',
#   '2018',
#   'and',
#   'ending',
#   'on',
#   'May',
#   '31',
#   ',',
#   '2020',
#   '(',
#   'the',
#   '"',
#   'Term',
#   '"',
#   ')',
#   '.'],
#  ['4', '.'],
#  ['Rent', '.'],
#  ['Tenant',
#   'will',
#   'pay',
#   'Landlord',
#   'a',
#   'monthly',
#   'rent',
#   'of',
#   '$',
#   '2',
#   ',',
#   '200.00',
#   'for',
#   'the',
#   'Term',
#   '.'],
#  ['Rent',
#   'will',
#   'be',
#   'payable',
#   'in',
#   'advance',
#   'and',
#   'due',
#   'on',
#   'the',
#   '2nd',
#   'day',
#   'of',
#   'each',
#   'month',
#   'during',
#   'the',
#   'Terrn',
#   '.'],
#  ['The',
#   'first',
#   'rent',
#   'payment',
#   'is',
#   'payable',
#   'to',
#   'Landlord',
#   'when',
#   'Tenant',
#   'signs',
#   'this',
#   'Agreement',
#   ',',
#   'Rent',
#   'for',
#   'any',
#   'period',
#   'during',
#   'the',
#   'Term',
#   'which',
#   'is',
#   'for',
#   'less',
#   'than',
#   'one',
#   'month',
#   'will',
#   'be',
#   'a',
#   'pro',
#   'rata',
#   'portion',
#   'of',
#   'the',
#   'monthly',
#   'installment',
#   '.'],
#  ['Rent',
#   'will',
#   'be',
#   'paid',
#   'to',
#   'Landlord',
#   'at',
#   'Landlord',
#   "'s",
#   'address',
#   'provided',
#   'herein',
#   '(',
#   'or',
#   'to',
#   'such',
#   'other',
#   'places',
#   'as',
#   'directed',
#   'by',
#   'Landlord',
#   ')',
#   'by',
#   'mail',
#   'or',
#   'in',
#   'person',
#   'by',
#   'one',
#   'of',
#   'the',
#   'following',
#   'methods',
#   ':',
#   'cashier',
#   "'s",
#   'check',
#   ',',
#   'money',
#   'order',
#   ',',
#   'credit',
#   'card',
#   ',',
#   'and',
#   'will',
#   'be',
#   'payable',
#   'in',
#   'U.S.',
#   'Dollars',
#   '.'],
#  ['5', '.'],
#  ['Late', 'Fee', '.'],
#  ['Rent',
#   'paid',
#   'after',
#   'the',
#   '2nd',
#   'day',
#   'of',
#   'each',
#   'month',
#   'will',
#   'be',
#   'deemed',
#   'as',
#   'late',
#   ';',
#   'and',
#   'if',
#   'rent',
#   'is',
#   'not',
#   'paid',
#   'within',
#   'one',
#   '(',
#   '1',
#   ')',
#   'days',
#   'after',
#   'such',
#   'due',
#   'date',
#   ',',
#   'Tenant',
#   'agrees',
#   'to',
#   'pay',
#   'a',
#   'late',
#   'charge',
#   'of',
#   '$',
#   '100.00',
#   '.'],
#  ['6', '.'],
#  ['Additional', 'Rent', '.'],
#  ['There',
#   'may',
#   'be',
#   'instances',
#   'under',
#   'this',
#   'Agreement',
#   'where',
#   'Tenant',
#   'may',
#   'be',
#   'required',
#   'to',
#   'pay',
#   'additional',
#   'charges',
#   'to',
#   'Landlord',
#   '.'],
#  ['All',
#   'such',
#   'charges',
#   'are',
#   'considered',
#   'additional',
#   'rent',
#   'under',
#   'this',
#   'Agreement',
#   'and',
#   'will',
#   'be',
#   'paid',
#   'with',
#   'the',
#   'next',
#   'regularly',
#   'scheduled',
#   'rent',
#   'payment',
#   '.'],
#  ['Landlord',
#   'has',
#   'the',
#   'same',
#   'rights',
#   'and',
#   'Tenant',
#   'has',
#   'the',
#   'same',
#   'obligations',
#   'with',
#   'respect',
#   'to',
#   'additional',
#   'rent',
#   'as',
#   'they',
#   'do',
#   'with',
#   'rent',
#   '.'],
#  ['Premises', '.'],
#  ['_', '.............', '.for'],
#  ['_',
#   'paymentotalutility',
#   'and',
#   'other',
#   'services',
#   'for',
#   'the',
#   '7',
#   '.'],
#  ['Utilities', '.'],
#  ['Tenant', 'is', 'responsible', '.'],
#  ['deposit'],
#  ['In', 'the', '8', '.'],
#  ['Security', 'Deposit', '.'],
#  ['Upon',
#   'signing',
#   'this',
#   'Agreement',
#   ',',
#   'Tenant',
#   "'",
#   'I',
#   'pay',
#   'a',
#   'security',
#   'ount',
#   'of',
#   '$',
#   '2',
#   ',',
#   '200.00',
#   'to',
#   'Landlo',
#   'upon',
#   'agreem'],
#  ['The', 'security', 'deposit', 'will', 'be', 'retained', 'enan'],
#  ['S', '-', 'Pefformance', '.fits'],
#  ['Obligations', 'under', 'this', 'Agreement', '.'],
#  ['The', 'security', 'y', 'Landtonsl', '-', 'rent', 'of', 'the', 'Term', '.'],
#  ['Tenant',
#   'will',
#   'be',
#   'epoiii',
#   'may',
#   'not',
#   'be',
#   'used',
#   'or',
#   'deducted',
#   'by',
#   'Tenant',
#   'as',
#   'the',
#   'last',
#   'month',
#   "'s",
#   'Tenant',
#   'returns',
#   'possession',
#   'of',
#   'the',
#   'Premises',
#   'to',
#   'Landlord',
#   'in',
#   'entitled',
#   'to',
#   'a',
#   'full',
#   'refund',
#   'of',
#   'the',
#   'security',
#   'deposit',
#   'if',
#   'ordinary',
#   'wear',
#   'and',
#   'tear',
#   'excepted',
#   '.'],
#  ['Within',
#   'fourteen',
#   '(',
#   '14',
#   ')',
#   'days',
#   'after',
#   'the',
#   'the',
#   'Same',
#   'condition',
#   'as',
#   'accepted',
#   ',',
#   'security',
#   'deposit',
#   'to',
#   'Tenant',
#   '(',
#   'minus',
#   'any',
#   'amount',
#   'termination',
#   'of',
#   'this',
#   'Agreement',
#   ',',
#   'Landlord',
#   'will',
#   'return',
#   'the',
#   '1'],
#  ['/12', 'Lease', 'Agreement', '(', 'Rev.', '133ED51', ')'],
#  ['3', 'DAY'],
#  ['NOTICE', 'TO', 'VACATE', 'April', '2', ',', '2019'],
#  ['Anthony',
#   'Saenz',
#   'and',
#   'Traci',
#   'Saenz',
#   '17623',
#   'Medina',
#   'Drive',
#   'Dallas',
#   ',',
#   'Texas',
#   '75287',
#   'TO'],
#  ['TENANT(S', ')', 'AND'],
#  ['ALL', 'OTHERS', 'IN', 'POSSESSION', 'OF', 'THE', 'PREMISES'],
#  ['LOCATED',
#   'AT',
#   ':',
#   '17623',
#   'Medina',
#   'Drive',
#   ',',
#   'Dallas',
#   ',',
#   'Texas',
#   '75287'],
#  ['PLEASE',
#   'TAKE',
#   'NOTICE',
#   'that',
#   'pursuant',
#   'to',
#   'the',
#   'lease',
#   'and/or',
#   'rental',
#   'agreement',
#   'dated',
#   'October',
#   '01',
#   ',',
#   '2018',
#   'under',
#   'which',
#   'you',
#   'hold',
#   'the',
#   'possession',
#   'of',
#   'the',
#   'herein',
#   'described',
#   'premises',
#   'there',
#   'is',
#   'now',
#   'due',
#   ',',
#   'unpaid',
#   'and',
#   'delinquent',
#   'rent',
#   'in',
#   'the',
#   'total',
#   'sum',
#   'of',
#   '$',
#   '1',
#   ',',
#   '400.00',
#   ',',
#   'representing',
#   'rent',
#   'due',
#   'for',
#   'the',
#   'period',
#   'from',
#   'April',
#   '1',
#   ',',
#   '2019',
#   'to',
#   'April',
#   '30',
#   ',',
#   '2019',
#   '.'],
#  ['In',
#   'accordance',
#   'with',
#   'the',
#   'lease',
#   'and/or',
#   'rental',
#   'agreement',
#   'dated',
#   'October',
#   '01',
#   ',',
#   '2018',
#   ',',
#   'you',
#   'owe',
#   'an',
#   'additional',
#   'sum',
#   'of',
#   '$',
#   '25.00',
#   'as',
#   'a',
#   'late',
#   'fee',
#   'and/or',
#   'charge',
#   '.'],
#  ['PLEASE',
#   'TAKE',
#   'FURTHER',
#   'NOTICE',
#   'that',
#   'within',
#   'THREE',
#   '(',
#   '3',
#   ')',
#   'days',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   ',',
#   'you',
#   'are',
#   'hereby',
#   'required',
#   'to',
#   'pay',
#   'the',
#   'above',
#   '-',
#   'listed',
#   'amounts',
#   'in',
#   'full',
#   'OR',
#   'vacate',
#   'the',
#   'subject',
#   'premises',
#   ',',
#   'move',
#   'out',
#   ',',
#   'and',
#   'deliver',
#   'up',
#   'possession',
#   'of',
#   'the',
#   'same',
#   'to',
#   'Ashley',
#   'Bonilla',
#   '.'],
#  ['Failure',
#   'to',
#   'pay',
#   'the',
#   'rent',
#   'and',
#   'late',
#   'fee',
#   'in',
#   'full',
#   'OR',
#   'vacate',
#   'the',
#   'premises',
#   'WITHIN',
#   'THREE',
#   '(',
#   '3',
#   ')'],
#  ['days',
#   'as',
#   'required',
#   'by',
#   'this',
#   'notice',
#   'will',
#   'result',
#   'in',
#   'forfeiture',
#   'of',
#   'the',
#   'lease',
#   'and/or',
#   'rental',
#   'agreement',
#   'and',
#   'will',
#   'cause',
#   'Landlord',
#   'to',
#   'institute',
#   'a',
#   'forcible',
#   'detainer',
#   'lawsuit',
#   'against',
#   'you',
#   'to',
#   'recover',
#   'rent',
#   ',',
#   'damages',
#   'and',
#   'possession',
#   'of',
#   'said',
#   'premises',
#   ',',
#   'plus',
#   'attorney',
#   "'s",
#   'fees',
#   'and',
#   'costs',
#   'of',
#   'suit',
#   ',',
#   'as',
#   'may',
#   'be',
#   'permitted',
#   'under',
#   'the',
#   'laws',
#   'of',
#   'the',
#   'State',
#   'of',
#   'Texas',
#   '.'],
#  ['The',
#   'exact',
#   'date',
#   'and',
#   'time',
#   'by',
#   'which',
#   'you',
#   'are',
#   'required',
#   'to',
#   'pay',
#   'in',
#   'full',
#   'or',
#   'vacate',
#   'is',
#   'April',
#   '5',
#   ',',
#   '2019',
#   'at',
#   '12:00',
#   'AM',
#   '.'],
#  ['THIS', 'IS'],
#  ['INTENDED'],
#  ['AS',
#   'A',
#   'THREE',
#   '(',
#   '3',
#   ')',
#   'DAY',
#   'LEGAL',
#   'NOTICE',
#   'FOR',
#   'THE',
#   'PURPOSE'],
#  ['OF', 'TERMINATING', 'YOUR', 'TENANCY', '.'],
#  ['THIS',
#   'TERMINATION',
#   'OF',
#   'TENANCY',
#   'IS',
#   'IN',
#   'ACCORDANCE',
#   'WITH',
#   'TEXAS',
#   'STATE',
#   'PROPERTY',
#   'CODE',
#   '24.005',
#   '.'],
#  ['LANDLORD', 'RESERVES', 'ALL'],
#  ['THE',
#   'RIGHTS',
#   'AND',
#   'REMEDIES',
#   'PROVIDED',
#   'UNDER',
#   'THE',
#   'RENTAL',
#   'AGREEMENT',
#   'AND',
#   'UNDER',
#   'APPLICABLE',
#   'LAWS',
#   'OF',
#   'THE',
#   'STATE',
#   'OF',
#   'TEXAS'],
#  ['INCLUDING',
#   'BUT',
#   'NOT',
#   'LIMITED',
#   'TO',
#   'DAMAGES',
#   'FOR',
#   'UNPAID',
#   'RENT'],
#  ['OR', 'PROPERTY', 'AND', 'NOTHING'],
#  ['IN', 'THIS', 'NOTICE'],
#  ['MAY', 'BE', 'CONSTRUED'],
#  ['AS', 'A', 'WAIVER', 'OF', 'SUCH', 'RIGHTS', 'AND', 'REMEDIES', '.'],
#  ['Dated', ':', 'April', '2', ',', '2019'],
#  ['By', ':', 'Ashley', 'Bonilla'],
#  ['-', 'ThavNtRy5', '"', ',', '-01', ':'],
#  ['DOCO9SoVV140'],
#  ['99', 'President', 'Street'],
#  ['Passaic',
#   'NJ',
#   '07055',
#   '7',
#   'Sherman',
#   'Street',
#   'Passaic',
#   ',',
#   'NJ',
#   '07055'],
#  ['March', '26', ',', '2019'],
#  ['Dear', 'Mr.', 'Mario', '-', 'Andre', 'Thomas', ','],
#  ['This',
#   'is',
#   'to',
#   'notify',
#   'you',
#   'that',
#   'as',
#   'of',
#   'April',
#   '1',
#   ',',
#   '2019',
#   'you',
#   'will',
#   'be',
#   'in',
#   'arrears',
#   'the',
#   'sum',
#   'of',
#   '$',
#   '3000',
#   'for',
#   'past',
#   'due',
#   'rent',
#   'inclusive',
#   'of',
#   'late',
#   'and',
#   'administrative',
#   'fees',
#   '.'],
#  ['Unless',
#   'full',
#   'restitution',
#   'is',
#   'made',
#   'by',
#   'April',
#   '10',
#   ',',
#   '2019',
#   ',',
#   'you',
#   'are',
#   'to',
#   'vacate',
#   'the',
#   'premises',
#   'at',
#   'the',
#   'above',
#   'stated',
#   'address',
#   'and',
#   'return',
#   'the',
#   'keys',
#   'to',
#   'this',
#   'office'],
#  ['no',
#   'later',
#   'than',
#   'the',
#   'close',
#   'of',
#   'business',
#   'on',
#   'said',
#   'day',
#   '.'],
#  ['Please',
#   'note',
#   ',',
#   'you',
#   'will',
#   'also',
#   'be',
#   'responsible',
#   'for',
#   'any',
#   'other',
#   'charges',
#   'incurred',
#   'during',
#   'this',
#   'period',
#   'as',
#   'per',
#   'the',
#   'rental',
#   'agreement',
#   'including',
#   'court',
#   'costs',
#   '.'],
#  ['It', 'is', '.'],
#  ['in',
#   'your',
#   'best',
#   'interest',
#   'to',
#   'resolve',
#   'this',
#   'matter',
#   'expeditiously',
#   '.'],
#  ['Jose', 'Oujo'],
#  ['Landlord', '6d', '5699891', '.'],
#  ['1.031', '.'],
#  ['eovuesginw', 'olisseiclxe'],
#  ['Le', '417.60', '61', '.'],
#  ['OJdv'],
#  ['2019', '/', '04', '/', '03', '10:00:07', '6', '/6'],
#  ['Three', '-', 'Day', 'Notice', 'to', 'Pay', 'Rent', 'or', 'Quit'],
#  ['To', ':'],
#  ['Jose', 'Martinez', '.'],
#  ['Gabriela', 'Martinez', 'Tracy', 'Martinez', ',', 'Alfred', 'Martinez', '.'],
#  ['all',
#   'tenants',
#   ',',
#   'subtenants',
#   ',',
#   'adult',
#   'occupants',
#   ',',
#   'and',
#   'others',
#   'in',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   'at',
#   '3356_11',
#   '4',
#   '/',
#   'fillhury',
#   'Avenue',
#   ',',
#   'city',
#   'of'],
#  ['Baldwin',
#   'Park',
#   ',',
#   'County',
#   'of',
#   'Los',
#   'Angeles',
#   ',',
#   'California',
#   ','],
#  ['Please',
#   'take',
#   'note',
#   'that',
#   'the',
#   'rent',
#   'on',
#   'these',
#   'promises',
#   'occupied',
#   'by',
#   'you',
#   ',',
#   'in',
#   'the',
#   'amount',
#   'of',
#   '24',
#   ',',
#   '100A',
#   ',',
#   'thrthe',
#   'period',
#   'from',
#   'March',
#   '1',
#   ',',
#   '2919',
#   'to',
#   'April',
#   '31',
#   '.',
#   '2019',
#   ',',
#   'is',
#   'now',
#   'due',
#   'and',
#   'payable',
#   '.'],
#  ['You',
#   'Are',
#   'Hereby',
#   'Required',
#   'to',
#   'pay',
#   'this',
#   'amount',
#   'within',
#   'THREE',
#   '(',
#   '3',
#   ')',
#   'days',
#   'from',
#   'the',
#   'date',
#   'of',
#   'service',
#   'on',
#   'you',
#   'of',
#   'this',
#   'notice',
#   'or',
#   'to',
#   'vacate',
#   'and',
#   'surrender',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   '.'],
#  ['In',
#   'the',
#   'event',
#   'you',
#   'fail',
#   'to',
#   'do',
#   'so',
#   ',',
#   'legal',
#   'proceedings',
#   'will',
#   'be',
#   'instituted',
#   'against',
#   'you',
#   'to',
#   'recover',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   ',',
#   'declare',
#   'the',
#   'forfeiture',
#   'of',
#   'the',
#   'rental',
#   'ageement',
#   'or',
#   'lease',
#   'under',
#   'which',
#   'you',
#   'occupy',
#   'the',
#   'premises',
#   ',',
#   'and',
#   'recover',
#   'rents',
#   ',',
#   'damages',
#   ',',
#   'and',
#   'costs',
#   'of',
#   'suit',
#   'RENT',
#   'IS',
#   'TO',
#   'BE',
#   'PAID',
#   'TO',
#   ':'],
#  ['[', 'X', ']', 'the', 'undersiened', ',', 'or'],
#  ['[', 'I', 'the', 'follmving', 'person', ':'],
#  ['AT'],
#  ['THE', ':', 'FOLLOWING', 'ADDRESS', '!'],
#  ['3356',
#   'Millbury',
#   'Avenue',
#   'BaWwin',
#   'Park',
#   ',',
#   'Calif',
#   'ia',
#   ',',
#   '917',
#   ',',
#   '0'],
#  ['phone', ':', 'Lk26', ')', '869', '-', '8672'],
#  ['IN', 'THE', 'FOLLOWING', 'MANNER', ':'],
#  ['[', 'X', 'I', 'in', 'Person', '.'],
#  ['tiatial',
#   'days',
#   'and',
#   'hours',
#   ',',
#   'for',
#   'rent',
#   'collection',
#   'are',
#   ':',
#   'Mqnday',
#   'through',
#   'Sunday',
#   '12PM',
#   'to'],
#  ['4I2',
#   'M',
#   ';',
#   '[',
#   ']',
#   'by',
#   'mail',
#   'to',
#   'the',
#   'person',
#   'and',
#   'address',
#   'indicated',
#   'above',
#   '[',
#   ']',
#   'by',
#   'deposit',
#   'to',
#   'account',
#   'at',
#   ',',
#   'a',
#   'financial',
#   'inMiMtion',
#   'located',
#   'within',
#   '$',
#   'miles',
#   'of',
#   'vour',
#   'rental',
#   'at',
#   'California',
#   '[',
#   ']',
#   'by',
#   'electronic',
#   'funds',
#   'transfer',
#   'procedure',
#   'previously',
#   'established',
#   '.'],
#  ['Ega', 'Pest'],
#  ['April', '0231019', 'Landlord', 'or', 'Managtr'],
#  ['Date', 'rroof', 'of', 'Servieo'],
#  ['I',
#   ',',
#   'the',
#   'undersigned',
#   ',',
#   'being',
#   'at',
#   'least',
#   'eighteen',
#   'years',
#   'of',
#   'age',
#   ',',
#   'served',
#   'this',
#   'notice',
#   ',',
#   'of',
#   'which',
#   'this',
#   'is',
#   'a',
#   'true',
#   'copy',
#   ',',
#   'on',
#   ',',
#   'One',
#   'of',
#   'the',
#   'occupants',
#   'listed',
#   'above',
#   'as',
#   'follows',
#   ':'],
#  ['APPnwed', "'", 'SCA', 'trijieS.', 'j100000'],
#  ['I', '03'],
#  ['10', '/', 'STATE', 'OF', 'MICHIGAN'],
#  ['DEMAND', 'FOR', 'POSSESSION'],
#  ['NONPAYMENT', 'OF', 'RENT'],
#  ['Landlord', '-', 'Tenant', 'TO'],
#  [':',
#   'Notice',
#   'to',
#   'mobile',
#   'home',
#   'owners',
#   'who',
#   'rent',
#   'Adam',
#   'Miles',
#   'and',
#   'Diamond',
#   'Matthews',
#   'and',
#   'All',
#   'Occupants',
#   'land',
#   'in',
#   'a',
#   'mobile',
#   'home',
#   'park',
#   ':'],
#  ['749W.', 'Southern', 'Ave', '.'],
#  ['Muskegon', ',', 'MI', '49441'],
#  ['If',
#   'you',
#   'have',
#   'been',
#   'late',
#   'on',
#   'payments',
#   'on',
#   'three',
#   'or',
#   'more',
#   'occasions',
#   'during',
#   'any',
#   '12',
#   '-',
#   'month',
#   'period',
#   'and',
#   'the',
#   'park',
#   'owner',
#   'has',
#   'given',
#   'you',
#   'a',
#   'written',
#   'demandfor',
#   'possession',
#   'for',
#   'nonpayment',
#   'of',
#   'rent',
#   'on',
#   'each',
#   'occasion',
#   ',',
#   'the',
#   'park',
#   'owner',
#   'may',
#   'have',
#   'just',
#   'cause',
#   'to'],
#  ['evict', 'you', '.'],
#  ['5', 'Homes', 'LLC', ',', 'says', 'that', 'you', 'owe', '$', '724', '.'],
#  ['5', 'rent', ':', '1', '.'],
#  ['YourlandlordAandlady', ',', 'Name', '(', 'type', 'or', 'print', ')'],
#  ['I',
#   'Address',
#   'or',
#   'description',
#   'of',
#   'premises',
#   'rented',
#   '(',
#   'if',
#   'different',
#   'from',
#   'mailing',
#   'address',
#   ')'],
#  ['749', 'W.', 'Southern', 'Ave', '.'],
#  ['Muskegon', ',', 'MI', '49441', '2', '.'],
#  ['If',
#   'you',
#   'owe',
#   'this',
#   'rent',
#   ',',
#   'you',
#   'must',
#   'do',
#   'one',
#   'of',
#   'the',
#   'following',
#   'within',
#   '7',
#   'days',
#   'from',
#   'the',
#   'date',
#   'this',
#   'notice',
#   'was',
#   'served',
#   '.'],
#  ['a.', 'Pay', 'the', 'rent', 'owed', '.', 'or'],
#  ['b.'],
#  ['Move', 'out', 'or', 'vacate', 'the', 'premises', '.'],
#  ['If',
#   'you',
#   'do',
#   'not',
#   'do',
#   'one',
#   'of',
#   'the',
#   'above',
#   ',',
#   'your',
#   'landlord',
#   '/',
#   'landlady',
#   'may',
#   'take',
#   'you',
#   'to',
#   'court',
#   'to',
#   'evict',
#   'you',
#   '.'],
#  ['If',
#   'you',
#   'move',
#   'out',
#   'or',
#   'vacate',
#   ',',
#   'you',
#   'may',
#   'still',
#   'owe',
#   'rent',
#   '.'],
#  ['3', '.'],
#  ['If',
#   'your',
#   'landlord',
#   '-',
#   'landlady',
#   'takes',
#   'you',
#   'to',
#   'court',
#   'to',
#   'evict',
#   'you',
#   'and',
#   'if',
#   'you',
#   'have',
#   'paid',
#   'the',
#   'rent',
#   ',',
#   'or',
#   'if',
#   'you',
#   'believe',
#   'there',
#   'is',
#   'a',
#   'good',
#   'reason',
#   'why',
#   'you',
#   'do',
#   'not',
#   'owe',
#   'the',
#   'rent',
#   ',',
#   'you',
#   'will',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'present',
#   'the',
#   'reasons',
#   'why',
#   'you',
#   'believe',
#   'you',
#   'should',
#   'not',
#   'be',
#   'evicted',
#   '.'],
#  ['4', '.'],
#  ['If',
#   'you',
#   'believe',
#   'there',
#   'is',
#   'a',
#   'good',
#   'reason',
#   'why',
#   'you',
#   'do',
#   'not',
#   'owe',
#   'the',
#   'rent',
#   'claimed',
#   'by',
#   'your',
#   'landlord',
#   '/',
#   'landlady',
#   ',',
#   'you',
#   'can',
#   'have',
#   'a',
#   'lawyer',
#   'advise',
#   'you',
#   '.'],
#  ['Call', 'him', 'or', 'her', 'soon', '.'],
#  ['02', '/', '11', '/', '2019', '1', 'lliv', 'iLc', 'Vi', ',', '.'],
#  ['6_er', ',', 't', '4', '..'],
#  ['Sio44', ',', 'of', 'owner'],
#  ['Of', 'premises', 'or', 'agent', '131'],
#  ['Sherman', 'Blvd', '.'],
#  ['Address', 'Muskegon', ',', 'MI', '49441'],
#  ['(', '231', ')', '722', '-', '1444', 'City', ',', 'state', ',', 'zip'],
#  ['Telephone', 'no', '.'],
#  ['HOW', 'TO', 'GET', 'LEGAL', 'HELP', '1', '.'],
#  ['Call', 'your', 'own', 'lawyer', '.'],
#  ['2', '.'],
#  ['If',
#   'you',
#   'do',
#   'not',
#   'have',
#   'an',
#   'attorney',
#   'but',
#   'have',
#   'money',
#   'to',
#   'retain',
#   'one',
#   ',',
#   'you',
#   'may',
#   'locate',
#   'an',
#   'attorney',
#   'through',
#   'the',
#   'State',
#   'Bar',
#   'of',
#   'Michigan'],
#  ['Lawyer',
#   'Referral',
#   'Service',
#   'at',
#   '1',
#   '-',
#   '800',
#   '-',
#   '968',
#   '-',
#   '0738',
#   'or',
#   'through',
#   'a',
#   'local',
#   'lawyer',
#   'referral',
#   'service',
#   '.'],
#  ['Lawyer',
#   'referral',
#   'services',
#   'should',
#   'belisted',
#   'in',
#   'the',
#   'yellow',
#   'pages',
#   'of',
#   'your',
#   'telephone',
#   'directory',
#   'or',
#   'you',
#   'can',
#   'find',
#   'a',
#   'local',
#   'lawyer',
#   'referral',
#   'service',
#   'at',
#   'www.michbar.ona',
#   '.'],
#  ['3', '.'],
#  ['If',
#   'you',
#   'do',
#   'not',
#   'have',
#   'an',
#   'attorney',
#   'and',
#   'can',
#   'not',
#   'pay',
#   'for',
#   'legal',
#   'help',
#   ',',
#   'you',
#   'may',
#   'qualify',
#   'for',
#   'assistance',
#   'through',
#   'a',
#   'local',
#   'legal',
#   'aid',
#   'office',
#   '.'],
#  ['Legal',
#   'aid',
#   'offices',
#   'should',
#   'be',
#   'listed',
#   'in',
#   'the',
#   'yellow',
#   'pages',
#   'of',
#   'your',
#   'telephone',
#   'directory',
#   'or',
#   'you',
#   'can',
#   'find',
#   'a',
#   'local',
#   'legal',
#   'aid',
#   'office',
#   'at',
#   'www.michiganlegalhelo.org'],
#  ['If',
#   'you',
#   'do',
#   'not',
#   'have',
#   'Internet',
#   'access',
#   'at',
#   'home',
#   ',',
#   'you',
#   'can',
#   'access',
#   'the',
#   'Internet',
#   'at',
#   'your',
#   'local',
#   'library',
#   '.'],
#  ['Tenant',
#   "'s",
#   'copy',
#   'MCL',
#   '600.5714(1)(a',
#   ')',
#   ',',
#   'MCL',
#   '600.5716',
#   ',',
#   'DC100',
#   '.'],
#  ['(',
#   '3',
#   '/',
#   '16',
#   ')',
#   'DEMAND',
#   'FOR',
#   'POSSESSION',
#   ',',
#   'NONPAYMENT',
#   'OF',
#   'RENT',
#   ','],
#  ['Landlord', '-', 'Tenant', 'MCL', '600.5718', ',', 'MCL', '600.5775(2)M'],
#  ['09:47:22', 'a.m.', '04', '-', '15', '-', '2019'],
#  ['717', '806', '-', '758', '-', '4512'],
#  ['ATT'],
#  ['Lla', 'ma', ',', '5000000', '?'],
#  ['41', '-', '1', '-', 'cibil4', '2716'],
#  ['40th', 'St', 'Lubbock', ',', 'TX', 'April', '4', ',', '2019'],
#  ['Marcella', 'B', 'Heintz', '4809'],
#  ['42nd', 'Street'],
#  ['Lubbock', 'TX', '79414'],
#  ['Janie', 'Lozoya', ','],
#  ['This',
#   'is',
#   'to',
#   'potify',
#   'you',
#   'that',
#   'your',
#   'failure',
#   'to',
#   'pay',
#   'the',
#   'rent',
#   'since',
#   'April',
#   '4',
#   '.',
#   '2019',
#   'at',
#   'the',
#   'apartment',
#   'addressed'],
#  ['2716',
#   '40th',
#   'St',
#   'Luhheek',
#   ',',
#   'TX',
#   '79413',
#   'has',
#   'rendered4you',
#   'in',
#   'violation',
#   'of',
#   'our',
#   'lease',
#   'agreement',
#   'dated',
#   'November',
#   '1',
#   ',',
#   '2017',
#   '.'],
#  ['The',
#   'amount',
#   'due',
#   'for',
#   'payment',
#   'sums',
#   'up',
#   'to',
#   '$',
#   '650.00',
#   '.'],
#  ['Please', 'consider', 'this', 'as', 'my', 'final', 'request', '.'],
#  ['If',
#   'you',
#   'fail',
#   'to',
#   'pay',
#   'the',
#   'amount',
#   'indicated',
#   'above',
#   'you',
#   'must',
#   'vacate',
#   'the',
#   'property',
#   'within',
#   'a',
#   'period',
#   'of',
#   '30',
#   'working',
#   'days',
#   ',',
#   'I',
#   'will',
#   'have',
#   'to',
#   'begin',
#   'an',
#   'eviction',
#   'proceeding',
#   'against',
#   'you',
#   '.'],
#  ['Kindly', 'cooperate', '.'],
#  ['Sincerely', ',', 'Marcella', 'B.', 'Heintz'],
#  ['Mar.', '1', '.'],
#  ['2319', '12', ':', '15PM'],
#  ['No', '.', '1242'],
#  ['P.', '5'],
#  ['NOTICE', 'TO', 'PAY', 'RENT', 'OR', 'QUIT', 'TO', ':'],
#  ['Jennifer', 'Steward', 'and', 'all', 'other', 'tenants'],
#  ['In',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   'described',
#   'as',
#   ':',
#   'Address',
#   ':'],
#  ['6A', 'Pieter', 'Schuyler', 'Ct', 'W', 'Albany', 'NY', '12210'],
#  ['PLEASE',
#   'TAKE',
#   'NOTICE',
#   'that',
#   'the',
#   'rent',
#   'is',
#   'now',
#   'due',
#   'and',
#   'payable',
#   'on',
# ...
#   'demand',
#   'for',
#   'payment',
#   'or',
#   'an',
#   'attempt',
#   'to',
#   'impose',
#   'personal',
#   'liability',
#   'for',
#   'a',
#   'discharged',
#   'debt',
#   '.'],
#  ['we',
#   'may',
#   'charge',
#   'you',
#   'a',
#   'Pee',
#   'Rif',
#   'up',
#   'to',
#   '$',
#   '40.00',
#   ')',
#   'for',
#   'any',
#   'payment',
#   'reteMed',
#   'Or',
#   'rejected',
#   'by',
#   'your',
#   'financial',
#   'institution',
#   '.'],
#  ['subject', 'to', 'applicable', 'lam', '.'],
#  ['Please',
#   'write',
#   'your',
#   'accourt',
#   'number',
#   'mall',
#   'checks',
#   'and',
#   'conetAndc',
#   ','],
#  ['At', '.'],
#  ['SEE', 'REVERSE', 'SIDE'],
#  ['FOR', 'IMPORTANT', 'INFORMATION'],
#  ['kraut', 'Number', ':', '870021963', '(', '0', ')'],
#  ['Dwayne', 'Foster'],
#  ['Flame',
#   'update',
#   'ehmell',
#   'Information',
#   'on',
#   'the',
#   'reverse',
#   'sale',
#   'of',
#   'this',
#   'women',
#   'Balance',
#   'due',
#   'for',
#   'charges',
#   'listed',
#   '*',
#   'eve',
#   ':',
#   '51',
#   ',',
#   '44593',
#   'as',
#   'of',
#   '1',
#   'Moodie',
#   'Ridge',
#   'Cr'],
#  ['January', '22', ',', '2019', 'Bark', 'of', 'America', ','],
#  ['N.A.', 'PO', 'Box', '16222'],
#  ['Wilmington',
#   ',',
#   'DE',
#   '19686',
#   '-',
#   '5222',
#   '870021963000000144593000144593',
#   '1',
#   ':'],
#  ['5136', '4900'],
#  ['581:13', 'WO', '2', '196', '30', 'gd', '989', ','],
#  ['L392', 'Jelsod', 'euAsma'],
#  ['eo', ':', 'oL.', '61', '.'],
#  ['1.0', 'ABA'],
#  [',', '-1H.Q.', ',', 'vs', '1', ',', '64', '.7', '-', '3', '-', 'Cucoo'],
#  ['(', 'pcsi6', 'NOTICE', 'TO', 'PAY', 'OR', 'OUIT'],
#  ['NOTICE', 'TO', ':'],
#  ['Martha',
#   'Aceves',
#   ',',
#   'TENANT',
#   'in',
#   'possession',
#   'and',
#   'all',
#   'others',
#   ':'],
#  ['TAKE', 'NOTICE', 'THAT', ':'],
#  ['I.',
#   'Pursuant',
#   'to',
#   'a',
#   'written',
#   'lease',
#   'dated',
#   'September',
#   '1',
#   ',',
#   '2018',
#   ',',
#   'you',
#   'are',
#   'obligated',
#   'to',
#   'pay',
#   'certain',
#   'rents',
#   'on',
#   'the',
#   'premises',
#   'described',
#   'as',
#   ':',
#   '2910',
#   'Weald',
#   'Way',
#   '#',
#   '513',
#   ',',
#   'Sacramento',
#   ',',
#   'CA',
#   '95833',
#   '(',
#   'the',
#   '"',
#   'Premises',
#   '"',
#   ')',
#   ',',
#   'of',
#   'which',
#   'you',
#   'now',
#   'hold',
#   'possession',
#   '.'],
#  ['2', '.'],
#  ['You',
#   'are',
#   'late',
#   'in',
#   'the',
#   'payment',
#   'of',
#   'rents',
#   'totaling',
#   '$',
#   '9',
#   ',',
#   '240.00',
#   '.'],
#  ['This',
#   'rent',
#   'was',
#   'due',
#   'on',
#   'October',
#   '1',
#   ',',
#   '2018',
#   'and',
#   'relates',
#   'to',
#   '$',
#   '1',
#   ',',
#   '475.00',
#   'for',
#   'the',
#   'months',
#   'of',
#   'October',
#   '2018',
#   'March',
#   '2019',
#   'plus',
#   'late',
#   'fees',
#   'totaling',
#   '$',
#   '390.00',
#   '3',
#   '.'],
#  ['You',
#   'are',
#   'hereby',
#   'required',
#   'to',
#   'PAY',
#   'the',
#   'said',
#   'rents',
#   ',',
#   'in',
#   'full',
#   ',',
#   'to',
#   'the',
#   'Landlord',
#   ',',
#   'or',
#   'its',
#   'agents',
#   ',',
#   'within',
#   '15',
#   'days',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['4', '.'],
#  ['If',
#   'you',
#   'fail',
#   'to',
#   'pay',
#   'the',
#   'above',
#   'mentioned',
#   'rent',
#   'within',
#   'the',
#   'time',
#   'period',
#   'mentioned',
#   'above',
#   ',',
#   'the',
#   'tenancy',
#   'will',
#   'be',
#   'forfeited',
#   'at',
#   'the',
#   'end',
#   'of',
#   'that',
#   'said',
#   'time',
#   'period',
#   '.'],
#  ['THIS',
#   'NOTICE',
#   'TO',
#   'PAY',
#   'RENT',
#   'IS',
#   'GIVEN',
#   'PURSUANT',
#   'TO',
#   'THE',
#   'APPLICABLE',
#   'LAWS'],
#  ['OF', 'THE', 'STATE', 'OF', 'CALIFORNIA'],
#  ['AND', 'IN', 'NO', 'WAY', 'IMPAIRS', 'OR', 'LIMITS', 'ANY', 'OF'],
#  ['THE',
#   'OTHER',
#   'REMEDIES',
#   'OR',
#   'RIGHTS',
#   'THAT',
#   'THE',
#   'LANDLORD',
#   'MAY',
#   'HAVE',
#   'UNDER'],
#  ['THE', 'LEASE'],
#  ['OR', 'UNDER', 'THE', 'SAID', 'LAWS', '.'],
#  ['Issued', 'on', ':'],
#  ['22th',
#   'day',
#   'of',
#   'February',
#   '2019',
#   '(',
#   '909',
#   ')',
#   '969',
#   '-',
#   '8021'],
#  ['Tenant', "'s", 'Name', ':', 'Martha', 'Aceves'],
#  ['Contact', 'Phone', 'Number', 'Larkspur', 'Woods', '2900', 'Weald', 'Way'],
#  ['Sacramento', ',', 'CA', '95833'],
#  ['Landlord', "'s", 'Name', ':'],
#  ['Shari', 'Carter'],
#  ['Contact', 'Address'],
#  ['bcso', ':'],
#  ['gg00000138159',
#   'P',
#   '-',
#   '3',
#   'NOTICE',
#   'TO',
#   'PAY',
#   'RENT',
#   'OR',
#   'QUIT',
#   'NOTICE',
#   'TO',
#   ':'],
#  ['Chiretha',
#   'Green',
#   ',',
#   'TENANT',
#   'in',
#   'possession',
#   'and',
#   'all',
#   'others',
#   ':'],
#  ['TAKE', 'NOTICE', 'THAT', ':', '1', '.'],
#  ['Pursuant',
#   'to',
#   'a',
#   'written',
#   'lease',
#   'dated',
#   'June',
#   '1',
#   ',',
#   '2017',
#   'you',
#   'are',
#   'obligated',
#   'to',
#   'pay',
#   'certain',
#   'rents',
#   'on',
#   'the',
#   'premises',
#   'described',
#   'as',
#   ':',
#   '3221',
#   'Woodworth',
#   'Place',
#   'Hazel',
#   'Crest',
#   ',',
#   'IL',
#   '60429',
#   '(',
#   'the',
#   '"',
#   'Premises',
#   '"',
#   ')',
#   ',',
#   'of',
#   'which',
#   'you',
#   'now',
#   'hold',
#   'possession',
#   '.'],
#  ['3', '.'],
#  ['You',
#   'are',
#   'late',
#   'in',
#   'the',
#   'payment',
#   'of',
#   'rents',
#   'totaling',
#   '$',
#   '1710',
#   '.'],
#  ['This',
#   'rent',
#   'was',
#   'due',
#   'on',
#   'March',
#   '10',
#   ',',
#   '2019',
#   'and',
#   'relates',
#   'to',
#   '$',
#   '1710',
#   'for',
#   'the',
#   'month',
#   'of',
#   'February',
#   '(',
#   'partial',
#   ')',
#   '&',
#   'March',
#   '2019',
#   '4',
#   '.'],
#  ['You',
#   'are',
#   'hereby',
#   'required',
#   'to',
#   'PAY',
#   'the',
#   'said',
#   'rents',
#   ',',
#   'in',
#   'full',
#   ',',
#   'to',
#   'the',
#   'landlord',
#   ',',
#   'or',
#   'its',
#   'agents',
#   ',',
#   'within',
#   '45',
#   'after',
#   'service',
#   'of',
#   'this',
#   'notice',
#   '.'],
#  ['4', '.'],
#  ['Payment',
#   'is',
#   'to',
#   'be',
#   'made',
#   'by',
#   'money',
#   'order',
#   'made',
#   'payable',
#   'to',
#   'Chante',
#   'Gamer',
#   '.'],
#  ['5', '.'],
#  ['If',
#   'you',
#   'fail',
#   'to',
#   'pay',
#   'the',
#   'above',
#   'mentioned',
#   'rent',
#   'within',
#   'the',
#   'time',
#   'period',
#   'mentioned',
#   'above',
#   ',',
#   'the',
#   'tenancy',
#   'will',
#   'be',
#   'forfeited',
#   'at',
#   'the',
#   'end',
#   'of',
#   'that',
#   'said',
#   'time',
#   'period',
#   'and',
#   'you',
#   'must',
#   'vacate',
#   'and',
#   'surrender',
#   'the',
#   'Premises',
#   'to',
#   'the',
#   'Landlord',
#   'by',
#   '12',
#   'noon',
#   'on',
#   'May',
#   '30',
#   ',',
#   '2019',
#   '.'],
#  ['THIS', 'NOTICE', 'TO', 'PAY', 'RENT'],
#  ['IS', 'GIVEN', 'PURSUANT', 'TO', 'THE', 'APPLICABLE', 'LAWS'],
#  ['OF', 'THE', 'STATE', 'OF', 'ILLINOIS'],
#  ['AND',
#   'IN',
#   'NO',
#   'WAY',
#   'IMPAIRS',
#   'OR',
#   'LIMITS',
#   'ANY',
#   'OF',
#   'THE',
#   'OTHER',
#   'REMEDIES',
#   'OR',
#   'RIGHTS',
#   'THAT',
#   'THE',
#   'LANDLORD',
#   'MAY',
#   'HAVE',
#   'UNDER',
#   'THE',
#   'LEASE',
#   'OR',
#   'UNDER',
#   'THE',
#   'SAID',
#   'LAWS',
#   '.'],
#  ['Issued',
#   'on',
#   ':',
#   '1st',
#   'day',
#   'of',
#   'April',
#   ',',
#   '2019',
#   'Chadae',
#   'GcoAta'],
#  ['Landlord', "'s", 'Name', ':'],
#  ['Chante', 'Gamer'],
#  ['17950', 'Locust', 'St', ',', 'Lansing', ',', 'IL', '60409'],
#  ['Contact', 'Address'],
#  ['7', ',', '4111r', '.'],
#  [',', "'", 'Oo', '(', ')', 'co'],
#  ['/Safi'],
#  ['org.i', 'EVICTION', 'NOTICE'],
#  ['Ms.', 'Latavia', 'Jackson', '8550', 'N', 'Sherman', 'Circle'],
#  ['Apt',
#   '503',
#   'Miramar',
#   ',',
#   'F1oricI',
#   '&',
#   '3102k',
#   'TO',
#   'THE',
#   'TENANT(S',
#   ')'],
#  ['AND',
#   'ANY',
#   'AND',
#   'ALL',
#   'OTHERS',
#   'IN',
#   'POSSESSION',
#   'OF',
#   'THE',
#   'PREMISES'],
#  ['LOCATED', 'AT'],
#  ['THE', 'AFOREMENTIONED', 'ADDRESS'],
#  [',', 'THIS', 'NOTICE', 'HAS', 'BEEN', 'SENT', 'TO'],
#  ['YOU',
#   'PURSUANT',
#   'TO',
#   'FLORIDA',
#   'RESIDENTIAL',
#   'LANDLORD',
#   'AND',
#   'TENANT'],
#  ['ACT', '0167'],
#  ['8356(3', ')'],
#  ['STATE', 'LAWS'],
#  ['AS', 'A', 'RESULT', 'OF', 'YOUR', 'BREACH', 'OF', 'THE', 'LEASE'],
#  ['AND',
#   '/',
#   'OR',
#   'YOUR',
#   'FAILURE',
#   'TO',
#   'PAY',
#   'RENT',
#   ',',
#   'LATE',
#   'FEES',
#   'AND',
#   '/',
#   'OR',
#   'OTHER',
#   'ASSOCIATED'],
#  ['COSTS'],
#  ['AND', '/', 'OR', 'FEES', '.'],
#  ['BE'],
#  ['IT',
#   'KNOWN',
#   'that',
#   'pursuant',
#   'to',
#   'your',
#   'signed',
#   'Lease',
#   'Agreement',
#   'dated',
#   '02',
#   '/',
#   '01',
#   '/',
#   '2019',
#   'and',
#   'where',
#   'you',
#   'are',
#   'in',
#   'possession',
#   'of',
#   'the',
#   'premises',
#   'located',
#   'at',
#   '8550',
#   'N',
#   'Sherman',
#   'Circle',
#   'Apt',
#   '503',
#   ',',
#   'Miramar',
#   ',',
#   'Florida',
#   '33025',
#   ',',
#   'there',
#   'is',
#   'currently',
#   'past',
#   'due',
#   ',',
#   'unpaid',
#   'and',
#   'delinquent',
#   'rent',
#   'and/or',
#   'fees',
#   'in',
#   'the',
#   'total',
#   'amount',
#   'of',
#   '$',
#   '1',
#   '436.00',
#   '.'],
#  ['The',
#   'total',
#   'amount',
#   'past',
#   'due',
#   'is',
#   'representative',
#   'of',
#   'unpaid',
#   'rent',
#   'from',
#   '03',
#   '/',
#   '01',
#   '/',
#   '2019',
#   'to',
#   '04',
#   '/',
#   '05',
#   '/',
#   '2019',
#   ',',
#   'plus',
#   'any',
#   'late',
#   'fee',
#   'charges',
#   'and/or',
#   'interest',
#   'accrued',
#   'on',
#   'the',
#   'past',
#   'due',
#   'rent',
#   '.'],
#  ['THEREFORE',
#   ',',
#   'you',
#   'are',
#   'hereby',
#   'provided',
#   'notice',
#   'that',
#   'all',
#   'past',
#   'due',
#   'monies',
#   'must',
#   'be',
#   'paid',
#   'in',
#   'full',
#   'by'],
#  ['no', 'later', 'than', '05', '/', '01', '/', '2019'],
#  ['or',
#   'you',
#   'must',
#   'vacate',
#   ',',
#   'quit',
#   ',',
#   'relinquish',
#   ',',
#   'move',
#   'out',
#   'or',
#   'deliver',
#   'up',
#   'possession',
#   'of',
#   'the',
#   'aforementioned',
#   'premises',
#   '.'],
#  ['Failure',
#   'to',
#   'correct',
#   'the',
#   'breach',
#   'of',
#   'your',
#   'Lease',
#   'Agreement',
#   'by',
#   'making',
#   'payment',
#   'in',
#   'full',
#   'within',
#   'the',
#   'stipulated',
#   'time',
#   'requested',
#   'by',
#   'this',
#   'notice',
#   'shall',
#   'result',
#   'in',
#   'the',
#   'cancellation',
#   ',',
#   'termination',
#   'or',
#   'forfeiture',
#   'of',
#   'the',
#   'Lease',
#   'Agreement',
#   '.'],
#  ['THE',
#   'LANDLORD',
#   'RESERVES',
#   'THE',
#   'RIGHTS',
#   'AND',
#   'REMEDIES',
#   'AFFORDED',
#   'TO',
#   'THEM'],
#  ['PURSUANT',
#   'TO',
#   'THE',
#   'SIGNED',
#   'LEASE',
#   '/',
#   'RENTAL',
#   'AGREEMENT',
#   'AND',
#   'IN',
#   'ACCORDANCE',
#   'WITH',
#   'APPLICABLE',
#   'LAWS',
#   'OF',
#   'THE',
#   'STATE',
#   'OF',
#   'FLORIDA',
#   'INCLUDING',
#   ',',
#   'BUT',
#   'NOT',
#   'LIMITED',
#   'TO',
#   ','],
#  ['UNPAID',
#   'RENT',
#   'AND',
#   '/',
#   'OR',
#   'PROPERTY',
#   'DAMAGES',
#   ',',
#   'AND',
#   'NOTHING',
#   'IN',
#   'THIS'],
#  ['NOTICE'],
#  ['MAY', 'BE', 'INTERPRETED'],
#  ['AS', 'A', 'RELINQUISHMENT', 'OF', 'SUCH', 'RIGHTS', 'AND', 'REMEDIES', '.'],
#  ['By',
#   ':',
#   't',
#   '(',
#   '31',
#   '41',
#   '-',
#   'en',
#   '(',
#   'Landlord',
#   'Signature',
#   ')',
#   '(',
#   'Date',
#   ')'],
#  ['Andre', 'Henry', '8550'],
#  ['N', 'Sherman', 'Circle', 'Apt', '503', 'Miramar', ',', 'Florida', '33025'],
#  ['646', '-', '858', '-', '8064', '_'],
#  ['-47.7mL', '-', 'N.', "'", '"', '`', 'Ze'],
#  ['DR', '.'],
#  ['KELLY', 'M.', 'NIMS', 'March', '1', ',', '2019'],
#  ['Tanya', 'Evans'],
#  ['121', 'Eagle', 'Street'],
#  ['Bridgeport', 'CT', '06607'],
#  ['Good', 'Morning', 'Tanya', ','],
#  ['I',
#   'called',
#   'you',
#   'several',
#   'times',
#   'yesterday',
#   'to',
#   'discuss',
#   'the',
#   'past',
#   'due',
#   'rent'],
#  ['I',
#   'understand',
#   'that',
#   'you',
#   'are',
#   'going',
#   'though',
#   'financial',
#   'problems',
#   'but'],
#  ['you',
#   'are',
#   '3',
#   'months',
#   'behind',
#   'and',
#   'now',
#   'March',
#   'is',
#   'due',
#   '.'],
#  ['I', 'am', 'sorry', 'to'],
#  ['inform',
#   'you',
#   'that',
#   'if',
#   'I',
#   'do',
#   'not',
#   'receive',
#   'your',
#   'back',
#   'rent',
#   '(',
#   '$',
#   '3000',
#   'phis',
#   '$',
#   '150',
#   'in',
#   'late',
#   'fees',
#   ')',
#   'and',
#   'your',
#   'current',
#   'rent',
#   'of',
#   '$',
#   '1000',
#   'which',
#   'totals',
#   '54150',
#   'by',
#   'March',
#   '10'],
#  ['"', ',', 'I', 'will', 'have', 'to', 'evict', 'you', '.'],
#  ['Let', "'s", 'get', 'back', 'on', 'track', '.'],
#  ['I',
#   'can',
#   'not',
#   'continue',
#   'to',
#   'let',
#   'you',
#   'fall',
#   'so',
#   'far',
#   'behind',
#   '.'],
#  ['Thank', 'you', ',', '376', 'Franklin', 'Avenue', '.'],
#  ['02A.'],
#  ['Brooklyn', 'NY', '1222'],
#  ['Tel', ':', '(', '347', ')', '448', '-', '0707'],
#  ['Email', ':'],
#  ['iamkeitynims@gmailcorn', '-', '-', '7', '\\', '-4', '-'],
#  ['C166Cx', ',', 'o', '3t111(', '/'],
#  ['414'],
#  ['Leonard', 'McCoy', ','],
#  ['Jr', 'Landlord', '2113'],
#  ['Quaker',
#   'Place',
#   'Chesapeake',
#   ',',
#   'VA',
#   '23325',
#   '757',
#   '-',
#   '424',
#   '-',
#   '2690'],
#  ['Nada', 'McCoy', '764', 'Creekside', 'Crescent'],
#  ['Chesapeake', ',', 'VA', '23320', '757', '-', '407', '-', '1819'],
#  ['February', '213', ',', '2_019'],
#  ['_'],
#  ['RE', ':'],
#  ['EVICTION', 'NOTICE'],
#  ['Dear', 'Ms.', 'McCoy', ','],
#  ['Multiple',
#   'warnings',
#   'have',
#   'been',
#   'issued',
#   'regarding',
#   'your',
#   'nonpayment',
#   'of',
#   'rent',
#   'as',
#   'agreed',
#   'upon',
#   'in',
#   'your',
#   'lease',
#   '.'],
#  ['Your',
#   'lease',
#   'agreement',
#   'clearly',
#   'states',
#   ',',
#   'I',
#   'will',
#   'proceed',
#   'with',
#   'the',
#   'eviction',
#   'process'],
#  ['If',
#   'your',
#   'rent',
#   'is',
#   'not',
#   'paid',
#   'in',
#   'full',
#   'by',
#   'the',
#   '6th',
#   'of',
#   'each',
#   'month',
#   '.'],
#  ['Due',
#   'to',
#   'the',
#   'failure',
#   'on',
#   'your',
#   'part',
#   'to',
#   'uphold',
#   'the',
#   'rental',
#   'agremi'],
#  ['ctenLaL7_64'],
#  ['Creeksicie', 'Crescent', ','],
#  ['CheSepeakeLVA', "9'320", ',', '.'],
#  ['Lhave_n0',
#   'choice',
#   'but',
#   'to_take_action',
#   'and',
#   'start',
#   'the',
#   'procese',
#   '-',
#   'ffriflogal',
#   'eviction',
#   'if',
#   'failure',
#   'to',
#   'comply',
#   'to',
#   'this',
#   'notice',
#   'by',
#   'March',
#   '5',
#   ',',
#   '2019',
#   '.'],
#  ['-', '-', '-'],
#  ['You',
#   'rent',
#   'is',
#   'past',
#   'due',
#   'by',
#   'klotal',
#   'amount',
#   'of',
#   '$',
#   '1000.00',
#   ','],
#  ['1or', 'the', 'month', 'on', 'February', '2019', '.'],
#  ['The', 'breakdown', 'is', 'as', 'follows', ':'],
#  ['$',
#   '900.00',
#   'per',
#   'month',
#   ',',
#   'late',
#   'fee',
#   'of',
#   '$',
#   '75.00',
#   'per',
#   'month'],
#  ['(',
#   'if',
#   'rerifis',
#   'not',
#   'received',
#   'by',
#   'the',
#   '61h',
#   'of',
#   'each',
#   'month',
#   ')',
#   'and',
#   '$',
#   '25.00',
#   'processing',
#   'fee',
#   '.'],
#  ['Your',
#   'immediate',
#   'response',
#   'would',
#   'be',
#   'realty',
#   'appreciated',
#   'in',
#   'this',
#   'matter',
#   ','],
#  ['If',
#   'you',
#   'have',
#   'any',
#   'questions',
#   'regarding',
#   'this',
#   'issue',
#   ',',
#   'please',
#   'contact',
#   'Mr.',
#   'McCoy',
#   'at',
#   '757',
#   '-',
#   '424',
#   '-',
#   '2690',
#   '.'],
#  ['Sincerely', ',', ',', 'Jeriv', ',', '-', '4"Pl'],
#  ['e'],
#  ['C4r', ','],
#  ['Leonard', 'McCoy', ',', 'Jr.', ',', 'e4', '5', ':'],
#  ["11'", ',', '4', '-', 'tr', '-', '0000'],
#  ['ta',
#   'c',
#   ',',
#   'a',
#   '913',
#   'Seth',
#   'Frost',
#   '103',
#   'Ash',
#   'Court',
#   'Hendersonville',
#   ',',
#   'Tennessee',
#   '37075',
#   'February',
#   '27',
#   ',',
#   '2019'],
#  ['Jonathan',
#   'Welliver',
#   '101',
#   'Ash',
#   'Court',
#   'Hendersonville',
#   ',',
#   'Tennessee',
#   '37075'],
#  ['Dear', 'Jonathan', 'Welliver', ':'],
#  ['This',
#   'letter',
#   'is',
#   'a',
#   'formal',
#   'notice',
#   'to',
#   'you',
#   'demanding',
#   'that',
#   'you',
#   'make',
#   'immediate',
#   'payment',
#   'of',
#   'the',
#   'unpaid',
#   'rent',
#   'due',
#   'under',
#   'the',
#   'terms',
#   'of',
#   'the',
#   'rental',
#   'agreement',
#   'covering',
#   'the',
#   'following',
#   'property',
#   ':'],
#  ['101', 'Ash', 'Court', 'Hendersonville', ',', 'Tennessee', '37075'],
#  ['As',
#   'of',
#   'February',
#   '27',
#   ',',
#   '2019',
#   ',',
#   'your',
#   'January',
#   'payment',
#   'is',
#   '31',
#   'days',
#   'past',
#   'due',
#   '.'],
#  ['Your', 'rent', 'was', 'due', 'on', 'January', '8', ',', '2019'],
#  ['The',
#   'following',
#   'is',
#   'an',
#   'itemization',
#   'of',
#   'the',
#   'total',
#   'amount',
#   'due',
#   ':',
#   'Unpaid',
#   'rent'],
#  ['$', '1', ',', '500.00', 'Total'],
#  ['$', '1', ','],
#  ['500.00'],
#  ['This',
#   'is',
#   'a',
#   'serious',
#   'situation',
#   'which',
#   'requires',
#   'your',
#   'immediate',
#   'attention',
#   '.'],
#  ['If',
#   'payment',
#   'is',
#   'not',
#   'received',
#   'by',
#   'March',
#   '5',
#   ',',
#   '2019',
#   ',',
#   'legal',
#   'action',
#   'to',
#   'enforce',
#   'your',
#   'obligations',
#   'under',
#   'the',
#   'rental',
#   'agreement',
#   'may',
#   'be',
#   'taken',
#   '.'],
#  ['I',
#   'can',
#   'be',
#   'contacted',
#   'if',
#   'you',
#   'have',
#   'any',
#   'questions',
#   'or',
#   'need',
#   'additional',
#   'information',
#   '.'],
#  ['I',
#   'can',
#   'be',
#   'contacted',
#   'by',
#   'phone',
#   'at',
#   '615',
#   '-',
#   '683',
#   '-',
#   '0489',
#   '.'],
#  ['Sincerely', ',', 'j', 'Seth', 'Frost', '-', 'w;;ww.011'],
#  ['Wwww']]

# %%
final_nerv = []

model_paths = ['./model-v6', './model-v7', './nlpv4', './nlpv5', './testingv1']

model = spacy.load(model_paths[4])
ner = model.get_pipe('ner')
for sentence in final_testing_data:
    doc = Doc(model.vocab, sentence)
    prediction = ner(doc)
    ents = [(x.start_char, x.end_char, x.label_) for x in prediction.ents]
    tags = biluo_tags_from_offsets(doc, ents)
    final_nerv.append(tags)
    
final_nerv
# Out:
# [['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-EvictionDateDefaulter', 'L-EvictionDateDefaulter'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'O',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O',
#   'O',
#   'U-StateDefaulter',
#   'B-PinCodeDefaulter',
#   'I-PinCodeDefaulter',
#   'L-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['B-NameDefaulter', 'L-NameDefaulter'],
#  ['B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'U-CityDefaulter',
#   'U-StateDefaulter',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'U-CityDefaulter',
#   'U-StateDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['U-StreetAddDefaulter',
#   'U-StreetAddDefaulter',
#   'U-StreetAddDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O',
#   'B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O'],
#  ['B-AmountDefaulter', 'L-AmountDefaulter', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-AmountDefaulter', 'L-AmountDefaulter'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'B-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-ThreatDefaulter', 'I-ThreatDefaulter', 'L-ThreatDefaulter', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'O', 'B-NameDefaulter', 'L-NameDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['U-CityDefaulter',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['B-NameDefaulter',
#   'I-NameDefaulter',
#   'I-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'B-NameDefaulter',
#   'L-NameDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['U-CityDefaulter', 'O', 'U-StateDefaulter', 'U-PinCodeDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['U-CityDefaulter', 'O', 'U-StateDefaulter', 'U-PinCodeDefaulter', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'U-ThreatDefaulter', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['B-CityDefaulter',
#   'L-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['B-NameDefaulter', 'I-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O', 'O'],
#  ['U-CityDefaulter', 'U-StateDefaulter', 'U-PinCodeDefaulter'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-DocDateDefaulter', 'L-DocDateDefaulter', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['U-CityDefaulter', 'U-StateDefaulter', 'U-PinCodeDefaulter'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['U-StateDefaulter',
#   'B-PinCodeDefaulter',
#   'I-PinCodeDefaulter',
#   'L-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['U-CityDefaulter', 'U-StateDefaulter', 'O', 'U-PinCodeDefaulter'],
#  ['O', 'O'],
#  ['B-StreetAddDefaulter', 'I-StreetAddDefaulter', 'L-StreetAddDefaulter'],
#  ['O', 'O', 'O', 'O'],
#  ['U-StateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PinCodeDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'B-PinCodeDefaulter',
#   'I-PinCodeDefaulter',
#   'L-PinCodeDefaulter',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter'],
#  ['U-CityDefaulter', 'O', 'U-StateDefaulter', 'U-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'B-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'U-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O'],
#  ['B-NameDefaulter', 'L-NameDefaulter'],
#  ['B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'O',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter'],
#  ['O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'O',
#   'B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['B-NameDefaulter', 'L-NameDefaulter'],
#  ['B-StreetAddDefaulter', 'I-StreetAddDefaulter', 'L-StreetAddDefaulter'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['U-CityDefaulter', 'U-StateDefaulter', 'U-PinCodeDefaulter'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'I-DocDateDefaulter',
#   'L-DocDateDefaulter'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-NameDefaulter',
#   'L-NameDefaulter',
#   'B-StreetAddDefaulter',
#   'I-StreetAddDefaulter',
#   'L-StreetAddDefaulter',
#   'U-CityDefaulter',
#   'O',
#   'U-StateDefaulter',
#   'U-PinCodeDefaulter'],
#  ['O', 'B-NameDefaulter', 'L-NameDefaulter', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-AmountDefaulter',
#   'I-AmountDefaulter',
#   'I-AmountDefaulter',
#   'L-AmountDefaulter',
#   'O'],
#  ['O', 'O', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'I-EvictionDateDefaulter',
#   'L-EvictionDateDefaulter',
#   'O',
#   'B-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'I-ThreatDefaulter',
#   'L-ThreatDefaulter',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O']]

# %%
ner_vals = []
for x in final_nerv:
    for e in x:
        ner_vals.append(e)
        
testing['ner'] = ner_vals
testing.to_excel('./team3_3.xlsx')

# %%
testing.shape
# Out:
# (7247, 5)
